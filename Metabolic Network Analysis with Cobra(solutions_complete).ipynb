# %% [markdown]
# # Building and Studying a tiny model

# %% [markdown]
# *Exercice 1*
#
# Manipulate the following tiny toy example by following the indications in the python notebook file. More specifically, perform an FBA optimization, a FVA, manipulate the model,….
# ~~~~
# R1 : 2A + B —> C
# R2 : B + C —> D + 2E
# R3 : 4A —> D
# R4 : —> A
# R5 : —> B
# R6 : D —>
# R7 : E —>
# ~~~~
# Preliminary question : Try to understand how cobra allows a modelization of this model
#
# Question 1 : Write the stoichiometric matrix
#
# Question 2 : Write the linear system that has to be solved
#
# Question 3 : Suppose that we observe V4 = 1 and V7 = 1 and solve the system
#
# Question 4 : Suppose that we observe V4 = 1 and V7 = 2 and solve the system
#
# Question 5 : All the reactions are irreversible. Plot the solution set. Suppose now that V4>1 and V7>1.
#
# Question 6 : One has V4 < 6 and V7<4. What is the solution that maximizes V4+V7 ?

# %%
# Importing the cobra library
import cobra
from cobra import Model, Reaction, Metabolite

# step 1 : Constructing a metabolic model

model = Model('example_model')

# set of reactions
reactions = dict()
for i in range(1,8):
    reactions["R"+str(i)] = Reaction("R"+str(i))
    reactions["R"+str(i)].name = "R"+str(i)
    reactions["R"+str(i)].subsystem = 'Body'
    reactions["R"+str(i)].lower_bound = 0.  # This is the default
    reactions["R"+str(i)].upper_bound = 1000.  # This is the default
    #reactions["R"+str(i)].objective_coefficient = 0. # this is the default
    print ("Creating R"+str(i))
# set of metabolites
A = Metabolite('A', name='A', compartment='c')
B = Metabolite('B', name='B', compartment='c')
C = Metabolite('C', name='C', compartment='c')
D = Metabolite('D', name='D', compartment='c')
E = Metabolite('E', name='E', compartment='c')
F = Metabolite('F', name='F', compartment='c')

reactions["R1"].add_metabolites({A:-2, B:-1, C: 1})
reactions["R2"].add_metabolites({B:-1, C:-1, D: 1, E: 2})
reactions["R3"].add_metabolites({A:-4, D: 1})
reactions["R4"].add_metabolites({A:1})
reactions["R5"].add_metabolites({B:1})
reactions["R6"].add_metabolites({D: -1})
reactions["R7"].add_metabolites({E: -1})


reactions["R4"].lower_bound = 1
reactions["R4"].upper_bound = 6
reactions["R7"].lower_bound = 1
reactions["R7"].upper_bound = 4

for i in range(1,8):
    model.add_reaction(reactions["R"+str(i)])
# Out:
# Creating R1
# Creating R2
# Creating R3
# Creating R4
# Creating R5
# Creating R6
# Creating R7

# %% [markdown]
# A few comments on the previous cell. In order to define a model in the cobra framework, one first need to instanciate the Model class with this line
#
#     model = Model('example_model')
#
# We also need to define the metabolites, this is done with
#
#     A = Metabolite('A', name='A', compartment='c'),....
#
# Finally, we define the reactions and add then to the model...
#
#     reactions["R1"] = Reaction("R1")
#     reactions["R1"].lower_bound = 0
#     reactions["R1"].upper_bound = 0
#     reactions["R1"].add_metabolites({A:-2, B:-1, C: 1})
#     model.add_reaction(reactions["R1"])

# %%
# setting the objective

model.reactions.R4.objective_coefficient=1
model.reactions.R7.objective_coefficient=1

# or alternative solution
model.objective= model.reactions.R4.flux_expression + model.reactions.R7.flux_expression

# %%
# Display some informations on the model (part 1)
print ("Number of metabolites = ",len(model.metabolites))
print ("Number of reactions = ",len(model.reactions))
# Out:
# Number of metabolites =  5
# Number of reactions =  7

# %%
# Display some informations on the model (part 2)

print ("Reaction 2 is ", model.reactions[2].build_reaction_string(), "lb = ", model.reactions[2].lower_bound, "ub = ", model.reactions[2].upper_bound)

# Question : Write a loop in order to get all the reactions

# Notice than we can iterate on reactions (or metabolites or genes,...)

for r in model.reactions:
    print(r.name, r.build_reaction_string())
# Out:
# Reaction 2 is  4 A --> D lb =  0.0 ub =  1000.0
# R1 2 A + B --> C
# R2 B + C --> D + 2 E
# R3 4 A --> D
# R4  --> A
# R5  --> B
# R6 D -->
# R7 E -->

# %% [markdown]
# # ⚠️ Important sample code
#
# model.reactions, model.metabolites, model.genes are lists. Thus we can iterate on them....
#
#     for r in model.reactions:
#         print(r.id)
#
#
#     for m in model.metabolites:
#         print(m.name)

# %%
# Perform a FBA optimization

# performing a FBA is done by using the optimize() function that 
# construct the appropriate LP problem and call the solver.

f=model.optimize()
print ("optimal value=",f.objective_value)
print ("corresponding fluxes = ",f.fluxes)

# a nicer view with pandas library
import pandas
pandas.DataFrame.from_dict({"fluxes": f.fluxes})
# Out:
# optimal value= 10.0
# corresponding fluxes =  R1    2.0
# R2    2.0
# R3    0.5
# R4    6.0
# R5    4.0
# R6    2.5
# R7    4.0
# Name: fluxes, dtype: float64
#     fluxes
# R1     2.0
# R2     2.0
# R3     0.5
# R4     6.0
# R5     4.0
# R6     2.5
# R7     4.0

# %% [markdown]
# # ⚠️ Important sample code
#
# For computing a FBA, we need a properly defined model with an objective function, then we use
#
#     model.optimize()

# %%
# Question: Get the minimal and maximal values of all the fluxes in the solution space

# for that, we need to change the objective and perform FBAs

for r in model.reactions:
    # for the maximal value of flux v_r (r is the reaction), we set obj(v)=v_r like this
    model.objective = r.flux_expression
    # the we optimize
    vr_max = model.optimize()
    # for the minimal value of flux v_r (r is the reaction), we set obj(v)=-v_r
    # and use the fact that min(v_r) = -max(-v_r)
    model.objective = -r.flux_expression
    # the we optimize
    vr_min = model.optimize()
    print(r.id, "min : ", -vr_min.objective_value," , max : ",vr_max.objective_value)
# Out:
# R1 min :  0.5  , max :  2.0
# R2 min :  0.5  , max :  2.0
# R3 min :  -0.0  , max :  1.25
# R4 min :  1.0  , max :  6.0
# R5 min :  1.0  , max :  4.0
# R6 min :  0.5  , max :  2.5
# R7 min :  1.0  , max :  4.0

# %%
model.objective = model.reactions.R4.flux_expression + model.reactions.R7.flux_expression

# compare with 
import cobra
cobra.flux_analysis.flux_variability_analysis(model, fraction_of_optimum=0.9)
# Out:
#     minimum  maximum
# R1     1.50     2.00
# R2     1.50     2.00
# R3     0.25     0.75
# R4     5.00     6.00
# R5     3.00     4.00
# R6     2.25     2.50
# R7     3.00     4.00

# %% [markdown]
# # ⚠️ Important sample code
#
# For computing a FVA, we need a properly defined model with an objective function, then we use
#
#     cobra.flux_analysis.flux_variability_analysis(model, fraction_of_optimum=0.9)
#
# with the fraction_of_optimum parameter to set the flexibility parameter.

# %%
# Extra ! A plot of the solution space by picking randomly some fluxes 
# belonging to the solution space


nbpoints=1000
PointsR4 = list()
PointsR7 = list()
PointsR1 = list()
PointsR2 = list()
fluxes_sample = cobra.sampling.sample(model,nbpoints)

# We are only interested by V_4 and V_7
for i in range(nbpoints):
    PointsR4.append(fluxes_sample.get("R4")[i])
    PointsR7.append(fluxes_sample.get("R7")[i])
    PointsR1.append(fluxes_sample.get("R1")[i])
    PointsR2.append(fluxes_sample.get("R2")[i])


# the following plot will be an approximation of the solution space

import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(PointsR4,PointsR7,"ro")
plt.show()

plt.plot(PointsR1,PointsR4,"bo")
plt.show()

plt.plot(PointsR1,PointsR2,"go")
plt.show()

# %% [markdown]
# # Study of bigger models

# %% [markdown]
# *Exercise 2*
#
# Get the ecoli_core model of Echerischia coli metabolism in the BiGG model repository here [http://bigg.ucsd.edu](http://bigg.ucsd.edu).
#
# 1. Execute a for loop on all the reactions and print their id and objective coefficient. Verify that the model possesses an objective and if not, use the model.reactions.get_by_id to set the objective coefficient of the biomass to 1.
# 2. Perform a FBA study. Count the number of reactions having a flux equal to zero.
# 3. Perform a FVA study. Report the reactions having a fixed flux. Classify the reactions into 3 classes: blocked reactions having a fixed flux equal to 0; essential reactions whose flux is either strictly positive or strictly negative; and alternative reactions whose flux can be positive or negative.
# 4. Perform a FVA study at 90%. Same questions as previously.
# 5. Study the effect of glucose disposability (i.e., store in an array the values of the optimal biomass, obtained by a FBA study, when the lower_bound of the ‘EX_glc_D_e’ reaction range from -1000 to 0 and plot the resulting values)
# 6. A reaction is said to be required for biomass iff setting the reaction flux to 0 imply a decrease of the biomass growth by more than 90%. Report all the required reactions.

# %%
import pandas
import cobra.test

# You can use this model from the tutorial
#model = cobra.test.create_test_model("ecoli")

# or this one that must be in the home folder
model = cobra.io.read_sbml_model("e_coli_core.xml")

# %% [markdown]
# # ⚠️ Important sample code
#
# Several file formats are used to store metabolic models (xml, json, mat,...). The cobra library implements several functions allowing to load a metabolic model from a file
#
# For SBML files (requires a supplementary library and has some restrictions on the SBML version)
#
#     model = cobra.io.read_sbml_model("filename.xml")
#
# For JSON files
#
#     model = cobra.io.load_json_model("filename.json")
#
# For matlab files (mainly used for compatibility purposes with the matlab version of the cobra toolbox)
#
#     model = cobra.io.load_matlab_model("filename.mat")
#
# Notice that there also exists functions to save a cobra metabolic model into a file (cobra.io.write_sbml_model, cobra.io.save_json_model, cobra.io.save_matlab_model,...). This allows for instance to make some simple format converters.
#
# From SBML to JSON
#
#     model = cobra.io.read_sbml_model("filename.xml")
#     cobra.io.save_json_model(model,"filename.json")

# %%
# Question: Execute a for loop on all the reactions and print their id and objective coefficient. 

for r in model.reactions:
    if not r.objective_coefficient == 0:
        print(r.id, r.objective_coefficient)

# notice that this verification is important because several models may not contains an objective function
# this test must be done before trying to compute a FBA of course
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-426bfc55ba78> in <module>
#       1 # Question: Execute a for loop on all the reactions and print their id and objective coefficient.
#       2
# ----> 3 for r in model.reactions:
#       4     if not r.objective_coefficient == 0:
#       5         print(r.id, r.objective_coefficient)
#
# NameError: name 'model' is not defined

# %%
# Question: how many reactions have a zero 0 for an optimal solution

# 1. perform a FBA

fba = model.optimize()

# 2. then count the number of zeros in fba.fluxes
zerofluxes = 0
for r in model.reactions:
    vr = fba.fluxes.get(r.id)
    if vr == 0:
        zerofluxes = zerofluxes + 1
print("Reaction with a null flux : ",zerofluxes)
# Out:
# Reaction with a null flux :  46

# %%
# Perform a FVA study. Classify the reactions into 3 classes.
# Blocked reactions : ----------[0]----------
# Essential reactions : ----------0--[------]-- or --[------]--0----------
# Alternative reactions : --------[--0---]-------

# 1. Computes a FVA (depending on alpha)

alpha = float(input("Enter the fraction of optimum value : "))
fva = cobra.flux_analysis.flux_variability_analysis(model, fraction_of_optimum=alpha)

# 1. Computes the blocked and essential reactions
blocked = 0
essential = 0
for r in model.reactions:
    vr_min = fva.get("minimum").get(r.id)
    vr_max = fva.get("maximum").get(r.id)
    if (abs(vr_min)<0.00000000001 and abs(vr_max)<0.00000000001):
        blocked = blocked + 1
    if vr_min>0.00000000001 or vr_max<-0.00000000001:
        essential = essential + 1

alternative = len(model.reactions)-blocked-essential

print(blocked, "blocked reactions")
print(essential, "essential reactions")
print(alternative, "alternative reactions")
# Out:
# Enter the fraction of optimum value : 0.9
# 8 blocked reactions
# 31 essential reactions
# 56 alternative reactions

# %% [markdown]
# # Genetic manipulations… and metabolic engineering

# %% [markdown]
# *Exercise 3*
#
# We will now work with the ecoli test model from cobrapy that contains some genetic reaction rules. `model = cobra.test.create_test_model("ecoli")`
# 1. Print the reaction rule of all the reactions.
# 2. Perform a single deletion analysis (cobra.flux_analysis.single_deletion) and report all the gene such that, when knocked out, the biomass production is less than 90% its optimal value.

# %%
import cobra
import cobra.test

model = cobra.test.create_test_model("ecoli")

# when logical rule exists for some reactions, they can be obtained by r.gene_reaction_rule

for r in model.reactions:
    print(r.id,r.gene_reaction_rule)
# Out:
# DM_4CRSOL
# DM_5DRIB
# DM_AACALD
# DM_AMOB
# DM_MTHTHF
# DM_OXAM
# Ec_biomass_iJO1366_WT_53p95M
# Ec_biomass_iJO1366_core_53p95M
# EX_12ppd__R_e
# EX_12ppd__S_e
# EX_14glucan_e
# EX_15dap_e
# EX_23camp_e
# EX_23ccmp_e
# EX_23cgmp_e
# EX_23cump_e
# EX_23dappa_e
# EX_26dap__M_e
# EX_2ddglcn_e
# EX_34dhpac_e
# EX_3amp_e
# EX_3cmp_e
# EX_3gmp_e
# EX_3hcinnm_e
# EX_3hpp_e
# EX_3hpppn_e
# EX_3ump_e
# EX_4abut_e
# EX_4hoxpacd_e
# EX_5dglcn_e
# EX_5mtr_e
# EX_LalaDglu_e
# EX_LalaDgluMdap_e
# EX_LalaDgluMdapDala_e
# EX_LalaLglu_e
# EX_ac_e
# EX_acac_e
# EX_acald_e
# EX_acgal_e
# EX_acgal1p_e
# EX_acgam_e
# EX_acgam1p_e
# EX_acmana_e
# EX_acmum_e
# EX_acnam_e
# EX_acolipa_e
# EX_acser_e
# EX_ade_e
# EX_adn_e
# EX_adocbl_e
# EX_ag_e
# EX_agm_e
# EX_akg_e
# EX_ala__B_e
# EX_ala__D_e
# EX_ala__L_e
# EX_alaala_e
# EX_all__D_e
# EX_alltn_e
# EX_amp_e
# EX_anhgm_e
# EX_arab__L_e
# EX_arbt_e
# EX_arbtn_e
# EX_arbtn__fe3_e
# EX_arg__L_e
# EX_ascb__L_e
# EX_asn__L_e
# EX_aso3_e
# EX_asp__L_e
# EX_btn_e
# EX_but_e
# EX_butso3_e
# EX_ca2_e
# EX_cbi_e
# EX_cbl1_e
# EX_cd2_e
# EX_cgly_e
# EX_chol_e
# EX_chtbs_e
# EX_cit_e
# EX_cl_e
# EX_cm_e
# EX_cmp_e
# EX_co2_e
# EX_cobalt2_e
# EX_colipa_e
# EX_colipap_e
# EX_cpgn_e
# EX_cpgn__un_e
# EX_crn_e
# EX_crn__D_e
# EX_csn_e
# EX_cu_e
# EX_cu2_e
# EX_cyan_e
# EX_cynt_e
# EX_cys__D_e
# EX_cys__L_e
# EX_cytd_e
# EX_dad__2_e
# EX_damp_e
# EX_dca_e
# EX_dcmp_e
# EX_dcyt_e
# EX_ddca_e
# EX_dgmp_e
# EX_dgsn_e
# EX_dha_e
# EX_dimp_e
# EX_din_e
# EX_dms_e
# EX_dmso_e
# EX_dopa_e
# EX_doxrbcn_e
# EX_dtmp_e
# EX_dump_e
# EX_duri_e
# EX_eca4colipa_e
# EX_enlipa_e
# EX_enter_e
# EX_etha_e
# EX_ethso3_e
# EX_etoh_e
# EX_f6p_e
# EX_fald_e
# EX_fe2_e
# EX_fe3_e
# EX_fe3dcit_e
# EX_fe3dhbzs_e
# EX_fe3hox_e
# EX_fe3hox__un_e
# EX_fecrm_e
# EX_fecrm__un_e
# EX_feenter_e
# EX_feoxam_e
# EX_feoxam__un_e
# EX_for_e
# EX_fru_e
# EX_frulys_e
# EX_fruur_e
# EX_fuc__L_e
# EX_fum_e
# EX_fusa_e
# EX_g1p_e
# EX_g3pc_e
# EX_g3pe_e
# EX_g3pg_e
# EX_g3pi_e
# EX_g3ps_e
# EX_g6p_e
# EX_gal_e
# EX_gal__bD_e
# EX_gal1p_e
# EX_galct__D_e
# EX_galctn__D_e
# EX_galctn__L_e
# EX_galt_e
# EX_galur_e
# EX_gam_e
# EX_gam6p_e
# EX_gbbtn_e
# EX_gdp_e
# EX_glc_e
# EX_glcn_e
# EX_glcr_e
# EX_glcur_e
# EX_glcur1p_e
# EX_gln__L_e
# EX_glu__L_e
# EX_gly_e
# EX_glyald_e
# EX_glyb_e
# EX_glyc_e
# EX_glyc__R_e
# EX_glyc2p_e
# EX_glyc3p_e
# EX_glyclt_e
# EX_gmp_e
# EX_gsn_e
# EX_gthox_e
# EX_gthrd_e
# EX_gtp_e
# EX_gua_e
# EX_h_e
# EX_h2_e
# EX_h2o_e
# EX_h2o2_e
# EX_h2s_e
# EX_hacolipa_e
# EX_halipa_e
# EX_hdca_e
# EX_hdcea_e
# EX_hg2_e
# EX_his__L_e
# EX_hom__L_e
# EX_hxa_e
# EX_hxan_e
# EX_idon__L_e
# EX_ile__L_e
# EX_imp_e
# EX_indole_e
# EX_inost_e
# EX_ins_e
# EX_isetac_e
# EX_k_e
# EX_kdo2lipid4_e
# EX_lac__D_e
# EX_lac__L_e
# EX_lcts_e
# EX_leu__L_e
# EX_lipa_e
# EX_lipa_cold_e
# EX_lipoate_e
# EX_lys__L_e
# EX_lyx__L_e
# EX_mal__D_e
# EX_mal__L_e
# EX_malt_e
# EX_malthx_e
# EX_maltpt_e
# EX_malttr_e
# EX_maltttr_e
# EX_man_e
# EX_man6p_e
# EX_manglyc_e
# EX_melib_e
# EX_meoh_e
# EX_met__D_e
# EX_met__L_e
# EX_metsox__R__L_e
# EX_metsox__S__L_e
# EX_mg2_e
# EX_mincyc_e
# EX_minohp_e
# EX_mmet_e
# EX_mn2_e
# EX_mnl_e
# EX_mobd_e
# EX_mso3_e
# EX_n2o_e
# EX_na1_e
# EX_nac_e
# EX_nh4_e
# EX_ni2_e
# EX_nmn_e
# EX_no_e
# EX_no2_e
# EX_no3_e
# EX_novbcn_e
# EX_o16a4colipa_e
# EX_o2_e
# EX_o2s_e
# EX_ocdca_e
# EX_ocdcea_e
# EX_octa_e
# EX_orn_e
# EX_orot_e
# EX_pacald_e
# EX_peamn_e
# EX_phe__L_e
# EX_pheme_e
# EX_pi_e
# EX_pnto__R_e
# EX_ppa_e
# EX_ppal_e
# EX_pppn_e
# EX_ppt_e
# EX_pro__L_e
# EX_progly_e
# EX_psclys_e
# EX_pser__L_e
# EX_ptrc_e
# EX_pydam_e
# EX_pydx_e
# EX_pydxn_e
# EX_pyr_e
# EX_quin_e
# EX_r5p_e
# EX_rfamp_e
# EX_rib__D_e
# EX_rmn_e
# EX_sbt__D_e
# EX_sel_e
# EX_ser__D_e
# EX_ser__L_e
# EX_skm_e
# EX_slnt_e
# EX_so2_e
# EX_so3_e
# EX_so4_e
# EX_spmd_e
# EX_succ_e
# EX_sucr_e
# EX_sulfac_e
# EX_tartr__D_e
# EX_tartr__L_e
# EX_taur_e
# EX_tcynt_e
# EX_thm_e
# EX_thr__L_e
# EX_thrp_e
# EX_thym_e
# EX_thymd_e
# EX_tma_e
# EX_tmao_e
# EX_tre_e
# EX_trp__L_e
# EX_tsul_e
# EX_ttdca_e
# EX_ttdcea_e
# EX_ttrcyc_e
# EX_tungs_e
# EX_tym_e
# EX_tyr__L_e
# EX_tyrp_e
# EX_uacgam_e
# EX_udpacgal_e
# EX_udpg_e
# EX_udpgal_e
# EX_udpglcur_e
# EX_ump_e
# EX_ura_e
# EX_urea_e
# EX_uri_e
# EX_val__L_e
# EX_xan_e
# EX_xmp_e
# EX_xtsn_e
# EX_xyl__D_e
# EX_xylu__L_e
# EX_zn2_e
# 12DGR120tipp
# 12DGR140tipp
# 12DGR141tipp
# 12DGR160tipp
# 12DGR161tipp
# 12DGR180tipp
# 12DGR181tipp
# 12PPDRtex b0241 or b0929 or b1377 or b2215
# 12PPDRtpp
# 12PPDStex b0241 or b0929 or b1377 or b2215
# 12PPDStpp
# 14GLUCANabcpp b4034 and b4033 and b4032 and b4035
# 14GLUCANtexi b4036
# 23CAMPtex b0241 or b0929 or b1377 or b2215
# 23CCMPtex b0241 or b0929 or b1377 or b2215
# 23CGMPtex b0241 or b0929 or b1377 or b2215
# 23CUMPtex b0241 or b0929 or b1377 or b2215
# 23DAPPAt2pp
# 23DAPPAtex b0241 or b0929 or b1377 or b2215
# 23PDE2pp b4213
# 23PDE4pp b4213
# 23PDE7pp b4213
# 23PDE9pp b4213
# 26DAHtex b0241 or b0929 or b1377 or b2215
# 2AGPA120tipp b2835
# 2AGPA140tipp b2835
# 2AGPA141tipp b2835
# 2AGPA160tipp b2835
# 2AGPA161tipp b2835
# 2AGPA180tipp b2835
# 2AGPA181tipp b2835
# 2AGPE120tipp b2835
# 2AGPE140tipp b2835
# 2AGPE141tipp b2835
# 2AGPE160tipp b2835
# 2AGPE161tipp b2835
# 2AGPE180tipp b2835
# 2AGPE181tipp b2835
# 2AGPEAT120 b2836
# 2AGPEAT140 b2836
# 2AGPEAT141 b2836
# 2AGPEAT160 b2836
# 2AGPEAT161 b2836
# 2AGPEAT180 b2836
# 2AGPEAT181 b2836
# 2AGPG120tipp b2835
# 2AGPG140tipp b2835
# 2AGPG141tipp b2835
# 2AGPG160tipp b2835
# 2AGPG161tipp b2835
# 2AGPG180tipp b2835
# 2AGPG181tipp b2835
# 2AGPGAT120 b2836
# 2AGPGAT140 b2836
# 2AGPGAT141 b2836
# 2AGPGAT160 b2836
# 2AGPGAT161 b2836
# 2AGPGAT180 b2836
# 2AGPGAT181 b2836
# 2DGULRGx b3553
# 2DGULRGy b3553
# 2DGULRx b3553
# 2DGULRy b3553
# 2MAHMP b0446 or b1134
# 34dhpactex b0241 or b0929 or b1377 or b2215
# 3AMACHYD b1009
# 3AMPtex b0241 or b0929 or b1377 or b2215
# 3CMPtex b0241 or b0929 or b1377 or b2215
# 3GMPtex b0929 or b1377 or b2215 or b0241
# 3HAD100 b0954 or b0180
# 3HAD120 b0180 or b0954
# 3HAD121 b0180 or b0954
# 3HAD140 b0954 or b0180
# 3HAD141 b0954 or b0180
# 3HAD160 b0954 or b0180
# 3HAD161 b0180 or b0954
# 3HAD180 b0954 or b0180
# 3HAD181 b0954 or b0180
# 3HAD40 b0954 or b0180
# 3HAD60 b0954 or b0180
# 3HAD80 b0954 or b0180
# 3HCINNMH b0347
# 3HPPPNH b0347
# 3HPPtex b1377 or b0929 or b2215 or b0241
# 3HPPtpp
# 3KGK b3580
# 3NTD2pp b4213
# 3NTD4pp b4213
# 3NTD7pp b4213
# 3NTD9pp b4213
# 3OAR100 b1093
# 3OAR120 b1093
# 3OAR121 b1093
# 3OAR140 b1093
# 3OAR141 b1093
# 3OAR160 b1093
# 3OAR161 b1093
# 3OAR180 b1093
# 3OAR181 b1093
# 3OAR40 b1093
# 3OAR60 b1093
# 3OAR80 b1093
# 3OAS100 b2323 or b1095
# 3OAS120 b1095 or b2323
# 3OAS121 b2323
# 3OAS140 b2323 or b1095
# 3OAS141 b2323
# 3OAS160 b2323 or b1095
# 3OAS161 b2323
# 3OAS180 b1095 or b2323
# 3OAS181 b1095
# 3OAS60 b1095 or b2323
# 3OAS80 b2323 or b1095
# 3OXCOAT b1397
# 3PEPTabcpp b1329 and b1244 and b1245 and b1246 and b1247
# 3PEPTtex b0241 or b0929 or b1377 or b2215
# 3UMPtex b0241 or b0929 or b1377 or b2215
# 42A12BOOXpp b1386
# 4HOXPACDtex b0241 or b0929 or b1377 or b2215
# 4HTHRS b0004
# 4PCP b1192
# 4PCPpp
# 4PEPTabcpp b1243 and b1244 and b1245 and b1246 and b1247
# 4PEPTtex b0241 or b0929 or b1377 or b2215
# 5DGLCNR b4266
# 5DGLCNt2rpp b4265
# 5DGLCNtex b0241 or b0929 or b2215 or b1377
# 5DOAN b0159
# 5MTRtex b1377 or b0929 or b2215 or b0241
# 5MTRtpp
# A5PISO b3197 or b2708
# AACPS1 b2836 and b1094
# AACPS2 b2836 and b1094
# AACPS3 b2836 and b1094
# AACPS4 b2836 and b1094
# AACPS5 b2836 and b1094
# AACPS6 b2836 and b1094
# AACPS7 b2836 and b1094
# AACPS8 b2836 and b1094
# AACPS9 b2836 and b1094
# AACTOOR
# AADDGT b4481
# AAMYL b1927
# AAMYLpp b3571
# AB6PGH b2901
# ABTA b2662 or b1302
# ABUTD b1444
# ABUTt2pp b2663
# ABUTtex b0241 or b0929 or b1377 or b2215
# ACACCT b2221 and b2222
# ACACT1r b2224 or b2342 or b3845
# ACACT2r b2342 or b3845
# ACACT3r b2342 or b3845
# ACACT4r b2342 or b3845
# ACACT5r b2342 or b3845
# ACACT6r b2342 or b3845
# ACACT7r b2342 or b3845
# ACACT8r b2342 or b3845
# ACACt2pp b2223
# ACACtex b0241 or b0929 or b1377 or b2215
# ACALD b0351 or b1241
# ACALDtex b0241 or b0929 or b1377 or b2215
# ACALDtpp s0001
# ACANTHAT b1463
# ACBIPGT b1993
# ACCOAC b0185 and b2316 and b3255 and b3256
# ACCOAL b4069
# ACGAL1PPpp
# ACGAL1Ptex b0241 or b0929 or b1377 or b2215
# ACGALtex b0241 or b0929 or b1377 or b2215
# ACGAM1PPpp
# ACGAM1Ptex b0241 or b0929 or b1377 or b2215
# ACGAMK b1119
# ACGAMT b3784
# ACGAptspp ( b2417 and b1101 and b2415 and b2416 ) or ( b0679 and b2415 and b2416 )
# ACGAtex b0241 or b0929 or b1377 or b2215
# ACGK b3959
# ACGS b2818
# ACHBS ( b3670 and b3671 ) or ( b0077 and b0078 )
# ACKr b3115 or b2296 or b1849
# ACLS ( b3670 and b3671 ) or ( b0077 and b0078 )
# ACM6PH b2428
# ACMAMUT b3794
# ACMANAptspp b1817 and b1818 and b1819 and b2415 and b2416
# ACMANAtex b0241 or b0929 or b1377 or b2215
# ACMUMptspp b2417 and b2429 and b2415 and b2416
# ACMUMtex b0241 or b0929 or b1377 or b2215
# ACNAMt2pp b3224
# ACNAMtex b4311 or b0929 or b2215
# ACNML b3225
# ACOAD1f b0221
# ACOAD2f b0221
# ACOAD3f b0221
# ACOAD4f b0221
# ACOAD5f b0221
# ACOAD6f b0221
# ACOAD7f b0221
# ACOAD8f b0221
# ACOATA b1094 and b1091
# ACODA b3957
# ACOLIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# ACONIs s0001
# ACONMT b1519
# ACONTa b0118 or b1276
# ACONTb b0118 or b1276
# ACOTA b1748 or b3359
# ACPPAT120 b1094 and b1090
# ACPPAT140 b1094 and b1090
# ACPPAT141 b1094 and b1090
# ACPPAT160 b1094 and b1090
# ACPPAT161 b1094 and b1090
# ACPPAT180 b1094 and b1090
# ACPPAT181 b1094 and b1090
# ACPS1 b3475 or b2563
# ACS b4069
# ACSERtex b1377 or b2215 or b0241 or b0929
# ACSERtpp b2578 or b1533
# ACt2rpp
# ACt4pp b4067
# ACtex b0241 or b0929 or b1377 or b2215
# ADA b1623
# ADCL b1096
# ADCS b3360 and b1812
# ADD b3665
# ADEt2rpp b3654 or b3714
# ADEtex b0241 or b0929 or b1377 or b2215
# ADK1 b0474
# ADK3 b0474
# ADK4 b0474
# ADMDC b0120
# ADNCYC b3806
# ADNK1 b0474
# ADNUC b0030
# ADNt2pp b2964 or b2393
# ADNt2rpp b2406
# ADNtex b0411
# ADOCBIK b1993
# ADOCBLS b1992
# ADOCBLabcpp b1711 and b1709 and b0158
# ADOCBLtonex b3966 and ( b1252 and b3005 and b3006 )
# ADPRDP b3397 or b3034
# ADPT b0469
# ADSK b2750
# ADSL1r b1131
# ADSL2r b1131
# ADSS b4177
# AGDC b0677
# AGM3PA b0110
# AGM3PApp b2435 or b2817 or b4169
# AGM3PH b1107
# AGM3Pt2pp b0433
# AGM4PA b0110
# AGM4PApp b2435 or b2817 or b4169
# AGM4PCP b1192
# AGM4PCPpp
# AGM4PH b1107
# AGM4Pt2pp b0433
# AGMH b1107
# AGMHE b3619
# AGMT b2937
# AGMt2pp b0433
# AGMtex b0241 or b0929 or b1377 or b2215
# AGPAT120 b3018
# AGPAT140 b3018
# AGPAT141 b3018
# AGPAT160 b3018
# AGPAT161 b3018
# AGPAT180 b3018
# AGPAT181 b3018
# AGPR b3958
# AGt3 b0572 and b0573 and b0574 and b0575
# AHCYSNS b0159
# AICART b4006
# AIRC2 b0522
# AIRC3 b0523
# AKGDH b0116 and b0726 and b0727
# AKGt2rpp b2587
# AKGtex b0241 or b0929 or b1377 or b2215
# ALAALAD b1488
# ALAALAabcpp ( b1487 and b1486 and b1485 and b1484 and b1483 ) or ( b3544 and b3543 and b3542 and b3541 and b3540 )
# ALAALAr b0381 or b0092
# ALAALAtex b0241 or b0929 or b1377 or b2215
# ALAGLUE b1325
# ALAR b1190 or b4053
# ALATA_D2 b2551 or b0870
# ALATA_L b2290 or b2379
# ALATA_L2 b0870 or b2551
# ALATRS b2697
# ALAabcpp b3454 and b3455 and b3457 and b3460 and b3456
# ALAt2pp b4208
# ALAt2rpp
# ALAt4pp b0007
# ALAtex b0241 or b0929 or b1377 or b2215
# ALCD19 b0356
# ALCD2x b1478 or b1241 or b0356
# ALDD19xr b1385
# ALDD2x b1300
# ALDD2y b3588
# ALDD3y b3588
# ALDD4
# ALLK b4084
# ALLPI b4090
# ALLTAMH b0516
# ALLTN b0512
# ALLTNt2rpp b0511
# ALLTNtex b0241 or b0929 or b1377 or b2215
# ALLULPE b4085
# ALLabcpp b4087 and b4088 and b4086
# ALLtex b0241 or b0929 or b1377 or b2215
# ALPATE160pp b0657 and b1677
# ALPATG160pp b0657 and b1677
# ALR2 b3012 or b0207 or b1781 or b3001
# ALR4x b3945
# ALTRH b3091
# AM3PA b0110
# AM4PA b0110
# AM4PCP b1192
# AMALT1 b3416
# AMALT2 b3416
# AMALT3 b3416
# AMALT4 b3416
# AMANAPEr b3223
# AMANK b3222
# AMAOTr b0774
# AMMQLT8 b3833
# AMPMS2 b3994
# AMPN b1982
# AMPTASECG b0237 or b0932 or b4260 or b2523
# AMPTASEPG b4260 or b0237 or b2523 or b0932
# AMPtex b2215 or b0929 or b1377 or b0241
# ANHGMtex b0241 or b0929 or b1377 or b2215
# ANHMK b1640
# ANPRT b1263
# ANS b1263 and b1264
# AOBUTDs s0001
# AOXSr2 b0776
# AP4AH b0049
# AP4AS b4129
# AP5AH b0049
# APCS b0121
# APG3PAT120 b3059
# APG3PAT140 b3059
# APG3PAT141 b3059
# APG3PAT160 b3059
# APG3PAT161 b3059
# APG3PAT180 b3059
# APG3PAT181 b3059
# APH120 b0968
# APH140 b0968
# APH141 b0968
# APH160 b0968
# APH161 b0968
# APH180 b0968
# APH181 b0968
# APPLDHr b3945
# APRAUR b0414
# ARAI b0062
# ARBTNR1
# ARBTNR2
# ARBTNR3
# ARBTNabcpp b0153 and b0151 and b0152
# ARBTNexs s0001
# ARBTNtex
# ARBTNtonex
# ARBTNtpp
# ARBTptspp ( b3722 and b2415 and b2416 ) or ( b2715 and b2415 and b2416 )
# ARBTtex b2215 or b1377 or b0241 or b0929
# ARBabcpp b1901 and b1900 and b4460
# ARBt2rpp b2841
# ARBt3ipp b1528
# ARBtex b0241 or b0929 or b1377 or b2215
# ARGAGMt7pp b4115
# ARGDC b4117
# ARGDCpp b2938
# ARGORNt7pp b1605
# ARGSL b3960
# ARGSS b3172
# ARGTRS b1876
# ARGabcpp ( b2310 and b2307 and b2306 and b2308 ) or ( b0863 and b0860 and b0861 and b0864 and b0862 )
# ARGt3pp b2923
# ARGtex b0241 or b0929 or b1377 or b2215
# ASAD b3433
# ASCBPL b4192
# ASCBptspp b2415 and b2416 and b4195 and b4194 and b4193
# ASCBtex b0241 or b0929 or b1377 or b2215
# ASNN b1767 or b0828
# ASNNpp b2957
# ASNS1 b0674
# ASNS2 b3744
# ASNTRS b0930
# ASNabcpp
# ASNt2rpp b1453
# ASNtex b0241 or b0929 or b1377 or b2215
# ASO3t8pp b3502
# ASO3tex b0241 or b0929 or b1377 or b2215
# ASP1DC b0131
# ASPCT ( b4244 and b4245 ) or b4245
# ASPK b0002 or b3940 or b4024
# ASPO3 b2574
# ASPO4 b2574
# ASPO5 b2574
# ASPO6 b2574
# ASPT b4139
# ASPTA b0928
# ASPTRS b1866
# ASPabcpp b0655 and b0654 and b0653 and b0652
# ASPt2_2pp b3528
# ASPt2_3pp b4138 or b4123
# ASPt2pp b4077
# ASPt2rpp
# ASPtex b0241 or b0929 or b1377 or b2215
# ASR b3503 and b1064
# AST b1747
# ATHRDHr b1539
# ATPHs s0001
# ATPM
# ATPPRT b2019
# ATPS4rpp ( ( b3736 and b3737 and b3738 ) and ( b3731 and b3732 and b3733 and b3734 and b3735 ) and b3739 ) or ( ( b3736 and b3737 and b3738 ) and ( b3731 and b3732 and b3733 and b3734 and b3735 ) )
# BALAt2pp b4208
# BALAtex b0241 or b0929 or b1377 or b2215
# BETALDHx b0312
# BETALDHy b0312
# BMOCOS b0827
# BMOGDS1 b3857 or ( b3857 and b3856 )
# BMOGDS2 b3857 or ( b3857 and b3856 )
# BPNT b4214
# BSORx b3551
# BSORy b3551
# BTNt2ipp
# BTNtex b2215 or b1377 or b0241 or b0929
# BTS5 b0775
# BUTCT b2221 and b2222
# BUTSO3abcpp ( b0936 and b0933 and b0934 ) or ( b0365 and b0366 and b0367 )
# BUTSO3tex b0241 or b0929 or b1377 or b2215
# BUTt2rpp b2223
# BUTtex b0241 or b0929 or b1377 or b2215
# BWCOGDS1 b3857 or ( b3857 and b3856 )
# BWCOGDS2 b3857 or ( b3857 and b3856 )
# BWCOS b0827
# CA2t3pp b1216
# CA2tex b0241 or b0929 or b1377 or b2215
# CADVtpp b4132
# CAT b1732 or b3942
# CAt6pp b3196
# CBIAT b1270
# CBItonex b3966 and ( b1252 and b3005 and b3006 )
# CBIuabcpp b1711 and b1709 and b0158
# CBL1abcpp b1711 and b1709 and b0158
# CBL1tonex b3966 and ( b1252 and b3005 and b3006 )
# CBLAT b1270
# CBMD s0001
# CBMKr b0521 or b0323 or b2874
# CBPS b0032 and b0033
# CCGS b0444
# CD2abcpp b3469
# CD2t3pp b3915 or b0752
# CD2tex b0241 or b0929 or b1377 or b2215
# CD2tpp b3040
# CDAPPA120 b3918
# CDAPPA140 b3918
# CDAPPA141 b3918
# CDAPPA160 b3918
# CDAPPA161 b3918
# CDAPPA180 b3918
# CDAPPA181 b3918
# CDGR b2794
# CDGS
# CDPMEK b1208
# CFAS160E b1661
# CFAS160G b1661
# CFAS180E b1661
# CFAS180G b1661
# CGLYabcpp b3544 and b3543 and b3542 and b3541 and b3540
# CGLYtex b0241 or b0929 or b1377 or b2215
# CHLabcpp b2128 and b2129 and b2130 and b2131
# CHLt2pp b0314 or b1801
# CHLtex b0241 or b0929 or b1377 or b2215
# CHOLD b0311
# CHORM b2599 or b2600
# CHORS b2329
# CHRPL b4039
# CHTBSptspp b2416
# CHTBStex b2215 or b0929 or b1377 or b0241
# CINNDO b2538 and b2539 and b2540 and b2542
# CITL ( b0615 and b0616 and b0617 ) and b0614
# CITt3pp
# CITt7pp b0612
# CITtex b0241 or b0929 or b1377 or b2215
# CLIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# CLPNH120pp
# CLPNH140pp
# CLPNH141pp
# CLPNH160pp
# CLPNH161pp
# CLPNH180pp
# CLPNH181pp
# CLPNS120pp b0789 or b1249
# CLPNS140pp b1249 or b0789
# CLPNS141pp b0789 or b1249
# CLPNS160pp b0789 or b1249
# CLPNS161pp b1249 or b0789
# CLPNS180pp b0789 or b1249
# CLPNS181pp b0789 or b1249
# CLt3_2pp b0155 or b1592
# CLtex b0241 or b0929 or b1377 or b2215
# CMPN
# CMPtex b0241 or b0929 or b1377 or b2215
# CMtex b1377 or b2215 or b0929 or b0241
# CMtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# CO2tex b0241 or b0929 or b1377 or b2215
# CO2tpp s0001
# COBALT2abcpp b3469
# COBALT2t3pp b0752 or b3915
# COBALT2tex b0241 or b0929 or b1377 or b2215
# COBALT2tpp b3040 or b3816
# COLIPAKpp b2174
# COLIPAPabctex b3200 and b3201 and b3199 and b4261 and b4262
# COLIPAabcpp b0914
# COLIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# CPGNR1
# CPGNR2
# CPGNR3
# CPGNUtex
# CPGNUtpp
# CPGNabcpp b0153 and b0151 and b0152
# CPGNexs s0001
# CPGNtonex b1102 and ( b1252 and b3005 and b3006 )
# CPH4S b2765
# CPMPS b0781 and b0783
# CPPPGO b2436
# CPPPGO2 b3867
# CRNBTCT b0038
# CRNCAL2 b0037
# CRNCAR b0036
# CRNCBCT b0038
# CRNCDH b0036
# CRNDCAL2 b0037
# CRNDabcpp b2677 and b2678 and b2679
# CRNDt2rpp b4111
# CRNDtex b1377 or b2215 or b0929 or b0241
# CRNabcpp b2677 and b2678 and b2679
# CRNt2rpp b4111
# CRNt7pp b0040
# CRNt8pp b0040
# CRNtex b0241 or b0929 or b1377 or b2215
# CS b0720
# CSND b0337
# CSNt2pp b0336
# CSNtex b0241 or b0929 or b1377 or b2215
# CTBTCAL2 b0037
# CTBTabcpp b2677 and b2678 and b2679
# CTBTt2rpp b4111
# CTECOAI6 b3846
# CTECOAI7 b3846
# CTECOAI8 b3846
# CTPS2 b2780
# CU1Opp b0123
# CU1abcpp b0484
# CU2abcpp b3469
# CU2tex b2215 or b0241 or b0929 or b1377
# CU2tpp b3040
# CUt3 b0572 and b0573 and b0574 and b0575
# CUtex b0241 or b0929 or b1377 or b2215
# CYANST b3425
# CYANSTpp b1308
# CYANtex b0241 or b0929 or b1377 or b2215
# CYNTAH b0340
# CYNTt2pp b0341
# CYNTtex b0241 or b0929 or b1377 or b2215
# CYSDDS b1919
# CYSDS b3708 or b3008
# CYSDabcpp
# CYSDtex b0241 or b0929 or b1377 or b2215
# CYSS b2414 or b2421
# CYSSADS b2810
# CYSTL b1622 or b3008
# CYSTRS b0526
# CYSabc2pp b0886 and b0887
# CYSabcpp
# CYStex b0241 or b0929 or b1377 or b2215
# CYStpp b2578 or b1533
# CYTBD2pp b0978 and b0979
# CYTBDpp ( b0978 and b0979 ) or ( b0733 and b0734 )
# CYTBO3_4pp b0429 and b0430 and b0431 and b0432
# CYTD b2143
# CYTDH b2162 or b0651 or b0030
# CYTDK2 b2066
# CYTDt2pp b2393 or b2964
# CYTDt2rpp b2406
# CYTDtex b0241 or b0929 or b1377 or b2215
# CYTK1 b0910
# CYTK2 b0910
# D__LACt2pp b3603 or b2975
# D__LACtex b0241 or b0929 or b1377 or b2215
# DAAD b1189
# DADA b1623
# DADK b0474
# DADNt2pp b2964 or b2393
# DADNtex b0411
# DAGK120 b4042
# DAGK140 b4042
# DAGK141 b4042
# DAGK160 b4042
# DAGK161 b4042
# DAGK180 b4042
# DAGK181 b4042
# DALAt2pp b4208
# DALAtex b0241 or b0929 or b1377 or b2215
# DAMPtex b0241 or b0929 or b1377 or b2215
# DAPAL b2871
# DAPDC b2838
# DAPE b3809
# DAPabcpp
# DAPtex b0241 or b0929 or b1377 or b2215
# DASYN120 b0175
# DASYN140 b0175
# DASYN141 b0175
# DASYN160 b0175
# DASYN161 b0175
# DASYN180 b0175
# DASYN181 b0175
# DATPHs s0001
# DB4PS b3041
# DBTS b0778
# DC6PH b1734
# DCAtex b0241 or b0929 or b1377 or b2215
# DCMPtex b0241 or b0929 or b1377 or b2215
# DCTPD b2065
# DCYTD b2143
# DCYTt2pp b2393 or b2964
# DCYTtex b0411
# DDCAtexi b2344
# DDGALK b3693
# DDGLCNt2rpp b3909
# DDGLCNtex b0929 or b1377 or b2215 or b0241
# DDGLK b3526
# DDPA b2601 or b0754 or b1704
# DDPGALA b4477
# DGK1 b3648
# DGMPtex b0241 or b0929 or b1377 or b2215
# DGSNt2pp b2964
# DGSNtex b0241 or b0929 or b1377 or b2215
# DHACOAH b1393
# DHAD1 b3771
# DHAD2 b3771
# DHAPT b1200 and b1199 and b1198 and b2415 and b2416
# DHAtex b0241 or b0929 or b1377 or b2215
# DHAtpp
# DHBD b0596
# DHBS b0594
# DHBSH
# DHCIND b2541
# DHCINDO b0348
# DHDPRy b0031
# DHDPS b2478
# DHFR b1606 or b0048
# DHFS b2315
# DHMPTR b1606
# DHNAOT4 b3930
# DHNCOAS b2262
# DHNCOAT b0736
# DHNPA2r b3058
# DHNPTE b3058
# DHORD2 b0945
# DHORD5 b0945
# DHORDfum
# DHORTS b1062
# DHPPD b2541
# DHPPDA2 b0414
# DHPS2 b3177
# DHPTDCs2 s0001
# DHPTDNR b0578
# DHPTDNRN b0578
# DHPTPE b2303
# DHQS b3389
# DHQTi b1693
# DIMPtex b0241 or b0929 or b1377 or b2215
# DINSt2pp b2964
# DINStex b0241 or b0929 or b1377 or b2215
# DKGLCNR1 b0207 or b3012
# DKGLCNR2x b3553
# DKGLCNR2y b3553
# DMATT b0421
# DMPPS b0029
# DMQMT b2232
# DMSOR1 ( b1587 and b1588 and b1589 and b1590 ) or ( b0894 and b0895 and b0896 )
# DMSOR1pp b1872 and b1873
# DMSOR2 b0894 and b0895 and b0896
# DMSOR2pp b1872 and b1873
# DMSOtex b0241 or b0929 or b1377 or b2215
# DMSOtpp s0001
# DMStex b0241 or b0929 or b1377 or b2215
# DNMPPA
# DNTPPA b0099 or b1865
# DOGULNR b3575
# DOPAtex b0241 or b0929 or b1377 or b2215
# DOXRBCNtex b1377 or b2215 or b0929 or b0241
# DOXRBCNtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# DPCOAK b0103
# DPR b0425 or b3774
# DRPA b4381
# DSBAO1 b3860 and b1185
# DSBAO2 b3860 and b1185
# DSBCGT b2893
# DSBDR ( b4136 and b2582 ) or ( b4136 and b3781 )
# DSBGGT b0604
# DSERDHr b1539
# DSERt2pp b4208
# DSERtex b0241 or b0929 or b1377 or b2215
# DTARTD b4122
# DTMPK b1098
# DTMPtex b0241 or b0929 or b1377 or b2215
# DUMPtex b0241 or b0929 or b1377 or b2215
# DURADx b2147 and b2146
# DURIK1 b1238
# DURIPP b4382 or b4384
# DURIt2pp b2964 or b2393
# DURItex b0411
# DUTPDP b3640 or b2251
# DXPRIi b0173
# DXPS b0420
# DXYLK b3564
# E4PD b2927 or b1779
# EAR100x b1288
# EAR100y b1288
# EAR120x b1288
# EAR120y b1288
# EAR121x b1288
# EAR121y b1288
# EAR140x b1288
# EAR140y b1288
# EAR141x b1288
# EAR141y b1288
# EAR160x b1288
# EAR160y b1288
# EAR161x b1288
# EAR161y b1288
# EAR180x b1288
# EAR180y b1288
# EAR181x b1288
# EAR181y b1288
# EAR40x b1288
# EAR40y b1288
# EAR60x b1288
# EAR60y b1288
# EAR80x b1288
# EAR80y b1288
# ECA4COLIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# ECA4OALpp b3622
# ECAP1pp b3793 and b3785
# ECAP2pp b3793 and b3785
# ECAP3pp b3793 and b3785
# ECAtpp b3792
# ECOAH1 b3846 or b2341
# ECOAH2 b3846 or b2341
# ECOAH3 b3846 or b2341
# ECOAH4 b3846 or b2341
# ECOAH5 b3846 or b2341
# ECOAH6 b3846 or b2341
# ECOAH7 b3846 or b2341
# ECOAH8 b3846 or b2341
# EDA b1850
# EDD b1851
# EDTXS1 b1054
# EDTXS2 b1855
# EDTXS3 b2378
# EDTXS4 b1855
# EGMEACPR b1288
# ENLIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# ENO b2779
# ENTCS b0583
# ENTERES b0585
# ENTERES2 b0585
# EPMEACPR b1288
# ETHAAL b2440 and b2441
# ETHAt2pp
# ETHAtex b0241 or b0929 or b1377 or b2215
# ETHSO3abcpp b0936 and b0933 and b0934
# ETHSO3tex b0241 or b0929 or b1377 or b2215
# ETOHtex b0241 or b0929 or b1377 or b2215
# ETOHtrpp s0001
# F6PA b0825 or b3946
# F6PP b0822
# F6Pt6_2pp b3666
# F6Ptex b0241 or b0929 or b1377 or b2215
# FA100ACPHi b0404
# FA120ACPHi b0404
# FA140ACPHi b0404
# FA141ACPHi b0404
# FA160ACPHi b0404
# FA161ACPHi b0404
# FA80ACPHi b0404
# FACOAE100 b0452
# FACOAE120 b0452
# FACOAE140 b0452
# FACOAE141 b0452
# FACOAE160 b0452
# FACOAE161 b0452
# FACOAE180 b0452
# FACOAE181 b0452
# FACOAE60 b0452
# FACOAE80 b0452
# FACOAL100t2pp b1805 or b1701
# FACOAL120t2pp b1701 or b1805
# FACOAL140t2pp b1701 or b1805
# FACOAL141t2pp b1701 or b1805
# FACOAL160t2pp b1701 or b1805
# FACOAL161t2pp b1805 or b1701
# FACOAL180t2pp b1701 or b1805
# FACOAL181t2pp b1805 or b1701
# FACOAL60t2pp b1805 or b1701
# FACOAL80t2pp b1805 or b1701
# FADRx b3844
# FADRx2 b2763 and b2764
# FALDH2 b0356
# FALDtex b0241 or b0929 or b1377 or b2215
# FALDtpp s0001
# FALGTHLs s0001
# FBA b2097 or b1773 or b2925
# FBA3 b2925
# FBP b3925 or b4232 or b2930
# FCI b2802
# FCLK b2803
# FCLPA b2738 or b2800
# FCLT b0475
# FDH4pp ( b3892 and b3893 and b3894 ) or ( b1474 and b1475 and b1476 )
# FDH5pp ( b1474 and b1475 and b1476 ) or ( b3892 and b3893 and b3894 )
# FDMO b0935
# FDMO2 b0935
# FDMO3 b0935
# FDMO4 b0935
# FDMO6 b0935
# FE2abcpp b3409
# FE2t2pp b2392
# FE2t3pp b3915
# FE2tex b0241 or b0929 or b1377 or b2215
# FE2tpp b3040
# FE3DCITabcpp b4290 and b4289 and b4288 and b4287
# FE3DCITtonex b4291 and ( b1252 and b3005 and b3006 )
# FE3DHBZR
# FE3DHBZSabcpp b0592 and b0588 and b0590 and b0589
# FE3DHBZStonex ( b0805 and ( b1252 and b3005 and b3006 ) ) or ( b2155 and ( b1252 and b3005 and b3006 ) )
# FE3HOXR1
# FE3HOXR2
# FE3HOXR3
# FE3HOXUtex
# FE3HOXUtpp
# FE3HOXabcpp b0153 and b0151 and b0152
# FE3HOXexs s0001
# FE3HOXtonex b0150 and ( b1252 and b3005 and b3006 )
# FE3Ri b3844
# FE3abcpp
# FE3tex b0241 or b0929 or b1377 or b2215
# FECRMR1
# FECRMR2
# FECRMR3
# FECRMUtex
# FECRMUtpp
# FECRMabcpp b0153 and b0151 and b0152
# FECRMexs s0001
# FECRMtonex b0150 and ( b1252 and b3005 and b3006 )
# FEENTERR1
# FEENTERR2
# FEENTERR3
# FEENTERabcpp b0592 and b0588 and b0590 and b0589
# FEENTERexs s0001
# FEENTERtex b3035
# FEENTERtonex b0584 and ( b1252 and b3005 and b3006 )
# FEENTERtpp b0591
# FEOXAMR1 b4367
# FEOXAMR2 b4367
# FEOXAMR3 b4367
# FEOXAMUtex
# FEOXAMUtpp
# FEOXAMabcpp b0153 and b0151 and b0152
# FEOXAMexs s0001
# FEOXAMtonex b0150 and ( b1252 and b3005 and b3006 )
# FEROpp b0123
# FESD1s s0001
# FESD2s s0001
# FESR b4209
# FFSD
# FHL ( b4079 and ( b2481 and b2482 and b2483 and b2484 and b2485 and b2486 and b2487 and b2488 and b2489 and b2490 ) ) or ( b4079 and ( b2719 and b2720 and b2721 and b2722 and b2723 and b2724 ) )
# FLDR2 ( b0684 and b3924 ) or ( b2895 and b3924 )
# FLVR b3844 or ( b2763 and b2764 )
# FLVRx b3844
# FMETTRS b3288
# FMNAT b0025
# FMNRx b0937 or b3844
# FMNRx2 b3844 or b0937 or ( b2763 and b2764 )
# FOMETRi b2912
# FORCT b2374
# FORt2pp b0904 or b2492
# FORtex b0241 or b0929 or b1377 or b2215
# FORtppi b0904 or b2492
# FRD2 b4151 and b4152 and b4153 and b4154
# FRD3 b4151 and b4152 and b4153 and b4154
# FRUK b2168
# FRULYSDG b3371
# FRULYSE b4474
# FRULYSK b3374
# FRULYSt2pp b3370
# FRULYStex b0241 or b0929 or b1377 or b2215
# FRUURt2rpp b4321
# FRUURtex b0241 or b0929 or b1377 or b2215
# FRUpts2pp b1817 and b1818 and b1819 and b2415 and b2416
# FRUptspp b2167 and b2169 and b2415 and b2416
# FRUtex b0241 or b0929 or b1377 or b2215
# FTHFD b1232
# FTHFLi
# FUCtex b0241 or b0929 or b1377 or b2215
# FUCtpp b2801
# FUM b1612 or b4122 or b1611
# FUMt2_2pp b3528
# FUMt2_3pp b4138 or b4123 or b0621
# FUMtex b0241 or b0929 or b1377 or b2215
# FUSAtex b1377 or b2215 or b0929 or b0241
# FUSAtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# G1PACT b3730
# G1PPpp b1002
# G1PTT b2039 or b3789
# G1Ptex b0241 or b0929 or b1377 or b2215
# G1SAT b0154
# G2PP b2533
# G2PPpp b4055
# G3PAT120 b1094 and b4041
# G3PAT140 b1094 and b4041
# G3PAT141 b1094 and b4041
# G3PAT160 b1094 and b4041
# G3PAT161 b1094 and b4041
# G3PAT180 b1094 and b4041
# G3PAT181 b1094 and b4041
# G3PCabcpp b3452 and b3453 and b3450 and b3451
# G3PCtex b0241 or b0929 or b1377 or b2215
# G3PD2 b3608
# G3PD5 ( b2241 and b2242 and b2243 ) or b3426
# G3PD6 b2241 and b2242 and b2243
# G3PD7 b2241 and b2242 and b2243
# G3PEabcpp b3452 and b3453 and b3450 and b3451
# G3PEtex b0929 or b1377 or b2215 or b0241
# G3PGabcpp b3452 and b3453 and b3450 and b3451
# G3PGtex b0241 or b0929 or b1377 or b2215
# G3PIabcpp b3452 and b3453 and b3450 and b3451
# G3PItex b0241 or b0929 or b1377 or b2215
# G3PSabcpp b3452 and b3453 and b3450 and b3451
# G3PStex b0241 or b0929 or b1377 or b2215
# G3PT b0822
# G5SADs s0001
# G5SD b0243
# G6PDA b0678
# G6PDH2r b1852
# G6PP b0822
# G6Pt6_2pp b3666
# G6Ptex b0241 or b0929 or b1377 or b2215
# GAL1PPpp b1002
# GAL1Ptex b0241 or b0929 or b1377 or b2215
# GALBDtex b0241 or b0929 or b1377 or b2215
# GALCTD b3128
# GALCTLO b4358
# GALCTND b4478
# GALCTNLt2pp b4356
# GALCTNLtex b2215 or b1377 or b0929 or b0241
# GALCTNt2pp b3691
# GALCTNtex b0241 or b0929 or b1377 or b2215
# GALCTt2rpp b2789 or b3127
# GALCTtex b0241 or b0929 or b1377 or b2215
# GALKr b2045 or b0757
# GALM2pp b0756
# GALS3 b4119
# GALT1 b3628
# GALTptspp b2094 and b2093 and b2092 and b2415 and b2416
# GALTtex b0241 or b0929 or b1377 or b2215
# GALURt2rpp b3093
# GALURtex b0241 or b0929 or b1377 or b2215
# GALUi b1236
# GALabcpp ( b2149 and b2150 and b2148 ) or ( b4231 and b4227 and b4485 and b4230 )
# GALt2pp b2943
# GALtex b0241 or b0929 or b1377 or b2215
# GAM6Pt6_2pp b3666
# GAMAN6Ptex b0241 or b0929 or b1377 or b2215
# GAMptspp b1817 and b1818 and b1819 and b2415 and b2416
# GAMtex b0241 or b0929 or b1377 or b2215
# GAPD b1779
# GARFT b2500
# GART b1849
# GBBTNtex b0241 or b0929 or b1377 or b2215
# GCALDD b1415
# GDMANE b2052
# GDPDPK b2784 or b3650
# GDPMNH b2051
# GDPMNP b2467
# GDPTPDP b3650
# GDPtex b1377 or b2215 or b0929 or b0241
# GF6PTA b3729
# GGGABADr b1300
# GGGABAH b1298
# GGPTRCO b1301
# GGPTRCS b1297
# GHBDHx b3882
# GHMT2r b2551
# GK1 b3648
# GLBRAN2 b3432
# GLCATr b0459
# GLCDpp b0124 or b0837
# GLCNt2rpp b4321 or b4476 or b3415 or b4265
# GLCNtex b0241 or b0929 or b1377 or b2215
# GLCP b3428 or b3417
# GLCP2 b3417 or b3428
# GLCRAL b3126
# GLCRD b2788 or b2787
# GLCRt2rpp b3127 or b2789
# GLCRtex b0241 or b0929 or b1377 or b2215
# GLCS1 b3429
# GLCTR1 b3631
# GLCTR2 b3627
# GLCTR3 b3626
# GLCUR1Ptex b0241 or b0929 or b1377 or b2215
# GLCURt2rpp b3909 or b3093
# GLCURtex b0241 or b0929 or b1377 or b2215
# GLCabcpp b2149 and b2150 and b2148
# GLCptspp ( b2417 and b1621 and b2415 and b2416 ) or ( b2417 and b1101 and b2415 and b2416 ) or ( b1817 and b1818 and b1819 and b2415 and b2416 )
# GLCt2pp b2943
# GLCtex b0241 or b0929 or b1377 or b2215
# GLCtexi b4036
# GLDBRAN2 b3431
# GLGC b3430
# GLNS b3870 or b1297
# GLNTRS b0680
# GLNabcpp b0811 and b0810 and b0809
# GLNtex b0241 or b0929 or b1377 or b2215
# GLTPD b2091
# GLU5K b0242
# GLUABUTt7pp b1492
# GLUCYS b2688
# GLUDC b3517 or b1493
# GLUDy b1761
# GLUN b1812 or b0485 or b1524
# GLUNpp b2957
# GLUPRT b2312
# GLUR b3967
# GLUSy b3212 and b3213
# GLUTRR b1210
# GLUTRS b2400
# GLUabcpp b0655 and b0654 and b0653 and b0652
# GLUt2rpp b4077
# GLUt4pp b3653
# GLUtex b0241 or b0929 or b1377 or b2215
# GLXCL b0507
# GLYALDtex b0241 or b0929 or b1377 or b2215
# GLYALDtpp b3927
# GLYAT b3617
# GLYBabcpp b2128 and b2129 and b2130 and b2131
# GLYBt2pp b1801 or b4111
# GLYBtex b0241 or b0929 or b1377 or b2215
# GLYC2Pabcpp b3452 and b3453 and b3450 and b3451
# GLYC2Ptex b2215 or b0241 or b0929 or b1377
# GLYC3Pabcpp b3452 and b3453 and b3450 and b3451
# GLYC3Pt6pp b2240
# GLYC3Ptex b0241 or b0929 or b1377 or b2215
# GLYCAt2rpp b2789 or b3127
# GLYCAtex b0241 or b0929 or b1377 or b2215
# GLYCDx b3945
# GLYCK b0514
# GLYCK2 b3124
# GLYCL b2904 and b2903 and b2905 and b0116
# GLYCLTDx b3553 or b1033
# GLYCLTDy b1033 or b3553
# GLYCLTt2rpp b3603 or b2975
# GLYCLTt4pp b4067
# GLYCLTtex b0241 or b0929 or b1377 or b2215
# GLYCTO2 b2979 and b4467 and b4468
# GLYCTO3 b2979 and b4467 and b4468
# GLYCTO4 b2979 and b4467 and b4468
# GLYCtex b0241 or b0929 or b1377 or b2215
# GLYCtpp b3927 or s0001
# GLYK b3926
# GLYOX b0212
# GLYOX3
# GLYTRS b3559 and b3560
# GLYt2pp b4208 or b1801
# GLYt2rpp
# GLYt4pp b0007
# GLYtex b0241 or b0929 or b1377 or b2215
# GMAND b2053
# GMHEPAT b3052
# GMHEPK b3052
# GMHEPPA b0200
# GMPR b0104
# GMPS2 b2507
# GMPtex b1377 or b2215 or b0241 or b0929
# GND b2029
# GNK b4268 or b3437
# GOFUCR b2052
# GP4GH b0049
# GPDDA1 b3449
# GPDDA1pp b2239
# GPDDA2 b3449
# GPDDA2pp b2239
# GPDDA3 b3449
# GPDDA3pp b2239
# GPDDA4 b3449
# GPDDA4pp b2239
# GPDDA5 b3449
# GPDDA5pp b2239
# GRTT b0421
# GRXR b1064 or b3610 or b1654 or b0849
# GSNK b0477
# GSNt2pp b2964
# GSNtex b0241 or b0929 or b1377 or b2215
# GSPMDA b2988
# GSPMDS b2988
# GTHOXtex b0241 or b0929 or b1377 or b2215
# GTHOr b3500
# GTHPi b1710
# GTHRDHpp b3447
# GTHRDabc2pp b0886 and b0887
# GTHRDabcpp b0829 and b0830 and b0831 and b0832
# GTHRDtex b0241 or b0929 or b1377 or b2215
# GTHS b2947
# GTPCI b2153
# GTPCII2 b1277
# GTPDPDP b3779
# GTPDPK b2784
# GTPHs s0001
# GTPtex b0241 or b0929 or b1377 or b2215
# GUACYC
# GUAD b2883
# GUAPRT b0238 or b0125
# GUAt2pp b3654
# GUAtex b0411
# GUAtpp
# GUI1 b3092
# GUI2 b3092
# GUR1PPpp
# H2O2tex b0241 or b0929 or b1377 or b2215
# H2Otex s0001 or b0957 or b3875 or b2215 or b0241 or b1319 or b1377 or b0929
# H2Otpp s0001 or b0875
# H2SO
# H2St1pp s0001
# H2Stex b0241 or b0929 or b1377 or b2215
# H2tex b0241 or b0929 or b1377 or b2215
# H2tpp s0001
# HACD1 b3846 or b2341
# HACD2 b3846 or b2341
# HACD3 b3846 or b2341
# HACD4 b3846 or b2341
# HACD5 b3846 or b2341
# HACD6 b3846 or b2341
# HACD7 b3846 or b2341
# HACD8 b3846 or b2341
# HADPCOADH3 b1395
# HBZOPT b4040
# HCINNMt2rpp b0353
# HCINNMtex b0241 or b0929 or b1377 or b2215
# HCO3E b0126 or b0339
# HCYSMT b0261
# HCYSMT2 b0261
# HDCAtexi b2344
# HDCEAtexi b2344
# HEMEOS b0428
# HEPK1 b3630
# HEPK2 b3625
# HEPT1 b3621
# HEPT2 b3620
# HEPT3 b3632
# HEPT4 b3623
# HETZK b2104
# HEX1 b2388
# HEX4
# HEX7 b0394
# HEXt2rpp b2223
# HG2abcpp b3469
# HG2t3pp b3915
# HG2tex b0241 or b0929 or b1377 or b2215
# HISTD b2020
# HISTP b2022
# HISTRS b2514
# HISabcpp b2309 and b2307 and b2306 and b2308
# HISt2rpp b0112
# HIStex b0241 or b0929 or b1377 or b2215
# HKNDDH b0349
# HKNTDH b0349
# HMBS b3805
# HMPK1 b2103 or b2418
# HOMt2pp b0813 or b3824
# HOMtex b0241 or b0929 or b1377 or b2215
# HOPNTAL b0352
# HPPK2 b0142
# HPPPNDO b0348
# HPPPNt2rpp b0353
# HPPPNtex b0929 or b1377 or b2215 or b0241
# HPYRI b0508
# HPYRRx b1033 or b3553
# HPYRRy b1033 or b3553
# HSDy b3940 or b0002
# HSK b0003
# HSST b4013
# HSTPT b2021
# HXAND b2866 and b2867 and b2868
# HXAtex b2215 or b0241 or b0929 or b1377
# HXCT b2221 and b2222
# HXPRT b0238 or b0125
# HYD1pp ( b0972 and b0973 and b0974 ) or ( b2994 and b2995 and b2996 and b2997 ) or ( b2719 and b2720 and b2721 and b2722 and b2723 and b2724 )
# HYD2pp ( b0972 and b0973 and b0974 ) or ( b2994 and b2995 and b2996 and b2997 )
# HYD3pp ( b0972 and b0973 and b0974 ) or ( b2994 and b2995 and b2996 and b2997 )
# HYPOE
# HYXNtex b0241 or b0929 or b1377 or b2215
# HYXNtpp
# Htex b0929 or b1377 or b2215 or b0241
# I2FE2SR b2530 and b2529
# I2FE2SS b3807 and b2530 and b2529
# I2FE2SS2 b3807 and b2530 and b2529
# I2FE2ST b2528 and b2529
# I4FE4SR b2529
# I4FE4ST b2528 and b2529
# ICDHyr b1136
# ICHORS b2265
# ICHORSi b0593
# ICHORT b0595
# ICL b4015
# ICYSDS b2530
# IDOND b4267
# IDOND2 b4267
# IDONt2rpp b4265
# IDONtex b0241 or b0929 or b1377 or b2215
# IG3PS b2023 and b2025
# IGPDH b2022
# IGPS b1262
# ILETA b3770
# ILETRS b0026
# ILEabcpp b3454 and b3455 and b3457 and b3460 and b3456
# ILEt2rpp b0401
# ILEtex b0241 or b0929 or b1377 or b2215
# IMPC b4006
# IMPD b2508
# IMPtex b0241 or b0929 or b1377 or b2215
# INDOLEt2pp ( b3265 and b3266 ) and b3035
# INDOLEt2rpp b3161
# INDOLEtex b0241 or b0929 or b1377 or b2215
# INOSTt4pp b3679
# INSH b0030
# INSK b0477
# INSTtex b0241 or b0929 or b1377 or b2215
# INSt2pp b2964
# INSt2rpp b2406
# INStex b0411
# IPDDI b2889
# IPDPS b0029
# IPMD b0073
# IPPMIa b0071 and b0072
# IPPMIb b0071 and b0072
# IPPS b0074
# ISETACabcpp ( b0365 and b0366 and b0367 ) or ( b0936 and b0933 and b0934 )
# ISETACtex b0241 or b0929 or b1377 or b2215
# K2L4Aabcpp b0914
# K2L4Aabctex b3200 and b3201 and b3199 and b4261 and b4262
# KARA1 b3774
# KARA2 b3774
# KAS14 b2323 or b1095
# KAS15 b1091
# KDOCT2 b0918
# KDOPP b3198
# KDOPS b1215
# KG6PDC b4196 or b3581
# Kabcpp ( b0698 and b0697 and b0696 ) or ( b0698 and b0697 and b0696 and b4513 )
# Kt2pp ( b1291 and b3290 and b3849 ) or b1250 or ( b1291 and b3290 and b1363 ) or b3747
# Kt3pp b1216 or b0842 or b3350 or b0047
# Ktex b0241 or b0929 or b1377 or b2215
# L__LACD2 b3605 or ( b0306 and b0307 and b0308 )
# L__LACD3 b3605 or ( b0306 and b0307 and b0308 )
# L__LACt2rpp b3603 or b2975
# L__LACtex b0929 or b1377 or b2215 or b0241
# LA4NTpp b2257
# LACZ b0344
# LACZpp b2132
# LADGMDH b1326
# LALADGLUtex b2215 or b1377 or b0241 or b0929
# LALADGLUtpp b1634 or b3496 or b4130 or b0709
# LALALGLUtex b2215 or b1377 or b0241 or b0929
# LALALGLUtpp b1634 or b3496 or b4130 or b0709
# LALDO2x b3945
# LALDO3
# LALGP b0237
# LCADi b1415
# LCARR
# LCARS b2799
# LCTSt3ipp b2170 or b0070 or b1528
# LCTStex b0241 or b0929 or b1377 or b2215
# LCTStpp b0343
# LDH_D b2133 or b1380
# LDH_D2 b2133
# LEUTAi b3770 or b4054
# LEUTRS b0642
# LEUabcpp ( b3454 and b3455 and b3457 and b3460 and b3456 ) or ( b3454 and b3455 and b3457 and b3458 and b3456 )
# LEUt2rpp b0401
# LEUtex b0241 or b0929 or b1377 or b2215
# LGTHL b1651
# LIPACabcpp b0914
# LIPAHT2ex b0622
# LIPAHTex b0622
# LIPAMPL b4386
# LIPATPT b4386
# LIPAabcpp b0914
# LIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# LIPOCT b0630
# LIPOS b0628
# LIPOt2pp
# LIPOtex b1377 or b2215 or b0929 or b0241
# LPADSS b0182
# LPLIPAL1A120pp b0494
# LPLIPAL1A140pp b0494
# LPLIPAL1A141pp b0494
# LPLIPAL1A160pp b0494
# LPLIPAL1A161pp b0494
# LPLIPAL1A180pp b0494
# LPLIPAL1A181pp b0494
# LPLIPAL1E120pp b0494
# LPLIPAL1E140pp b0494
# LPLIPAL1E141pp b0494
# LPLIPAL1E160pp b0494
# LPLIPAL1E161pp b0494
# LPLIPAL1E180pp b0494
# LPLIPAL1E181pp b0494
# LPLIPAL1G120pp b0494
# LPLIPAL1G140pp b0494
# LPLIPAL1G141pp b0494
# LPLIPAL1G160pp b0494
# LPLIPAL1G161pp b0494
# LPLIPAL1G180pp b0494
# LPLIPAL1G181pp b0494
# LPLIPAL2A120 b3825
# LPLIPAL2A140 b3825
# LPLIPAL2A141 b3825
# LPLIPAL2A160 b3825
# LPLIPAL2A161 b3825
# LPLIPAL2A180 b3825
# LPLIPAL2A181 b3825
# LPLIPAL2ATE120 b3825
# LPLIPAL2ATE140 b3825
# LPLIPAL2ATE141 b3825
# LPLIPAL2ATE160 b3825
# LPLIPAL2ATE161 b3825
# LPLIPAL2ATE180 b3825
# LPLIPAL2ATE181 b3825
# LPLIPAL2ATG120 b3825
# LPLIPAL2ATG140 b3825
# LPLIPAL2ATG141 b3825
# LPLIPAL2ATG160 b3825
# LPLIPAL2ATG161 b3825
# LPLIPAL2ATG180 b3825
# LPLIPAL2ATG181 b3825
# LPLIPAL2E120 b3825
# LPLIPAL2E140 b3825
# LPLIPAL2E141 b3825
# LPLIPAL2E160 b3825
# LPLIPAL2E161 b3825
# LPLIPAL2E180 b3825
# LPLIPAL2E181 b3825
# LPLIPAL2G120 b3825
# LPLIPAL2G140 b3825
# LPLIPAL2G141 b3825
# LPLIPAL2G160 b3825
# LPLIPAL2G161 b3825
# LPLIPAL2G180 b3825
# LPLIPAL2G181 b3825
# LSERDHr b1539
# LYSDC b0186 or b4131
# LYSTRS b4129 or b2890
# LYSabcpp b2310 and b2307 and b2306 and b2308
# LYSt2pp b2156
# LYSt3pp b2923
# LYStex b0241 or b0929 or b1377 or b2215
# LYXI b3903
# LYXt2pp b3907
# LYXtex b0241 or b0929 or b1377 or b2215
# M1PD b3600
# MACPD b2323
# MALCOAMT b0777
# MALDDH b1800
# MALDt2_2pp b3528
# MALDtex b2215 or b1377 or b0241 or b0929
# MALS b4014 or b2976
# MALTATr b0459
# MALTHXabcpp b4034 and b4033 and b4032 and b4035
# MALTHXtexi b4036
# MALTPTabcpp b4034 and b4033 and b4032 and b4035
# MALTPTtexi b4036
# MALTTRabcpp b4034 and b4033 and b4032 and b4035
# MALTTRtexi b4036
# MALTTTRabcpp b4034 and b4033 and b4032 and b4035
# MALTTTRtexi b4036
# MALTabcpp b4034 and b4033 and b4032 and b4035
# MALTptspp b2417 and b1621 and b2415 and b2416
# MALTtexi b4036
# MALt2_2pp b3528
# MALt2_3pp b4123 or b4138
# MALt3pp
# MALtex b0241 or b0929 or b1377 or b2215
# MAN1PT2 b2049
# MAN6PI b1613
# MAN6Pt6_2pp b3666
# MAN6Ptex b0241 or b0929 or b1377 or b2215
# MANAO b4323
# MANGLYCptspp b0731 and b2415 and b2416
# MANGLYCtex b0241 or b0929 or b1377 or b2215
# MANPGH b0732
# MANptspp b1817 and b1818 and b1819 and b2415 and b2416
# MANtex b0241 or b0929 or b1377 or b2215
# MCITD b0334
# MCITL2 b0331
# MCITS b0333
# MCOATA b1094 and b1092
# MCPST b2521
# MCTP1App b0084 or b0635 or b0149 or b3396
# MCTP1Bpp b0149 or b3396
# MCTP2App b0084 or b0635 or b3396 or b0149
# MDDCP1pp b0632 or b3182 or b0839 or b2010
# MDDCP2pp b0632 or b3182 or b0839 or b2010
# MDDCP3pp b0632 or b3182 or b0839 or b2010
# MDDCP4pp b0632 or b3182 or b0839 or b2010
# MDDCP5pp b0632 or b3182 or b0839 or b2010
# MDDEP1pp b3182 or b2328 or b2134
# MDDEP2pp b3182 or b2328 or b2134
# MDDEP3pp b3182 or b2328 or b2134
# MDDEP4pp b3182 or b2328 or b2134
# MDH b3236
# MDH2 b2210
# MDH3 b2210
# ME1 b1479
# ME2 b2463
# MECDPDH5 ( b2895 and b2515 ) or ( b0684 and b2515 )
# MECDPS b2746
# MELIBt2pp b4120
# MELIBt3ipp b1528
# MELIBtex b0241 or b0929 or b1377 or b2215
# MEOHtex b1377 or b0929 or b2215 or b0241
# MEOHtrpp s0001
# MEPCT b2747
# METAT b2942
# METDabcpp b0198 and b0199 and b0197
# METDtex b0241 or b0929 or b1377 or b2215
# METOX1s s0001
# METOX2s s0001
# METS b4019 or b3829
# METSOX1abcpp
# METSOX1tex b0241 or b0929 or b1377 or b2215
# METSOX2abcpp
# METSOX2tex b0241 or b0929 or b1377 or b2215
# METSOXR1 ( b4219 and b2582 ) or ( b4219 and b3781 ) or ( b3551 and b2582 ) or ( b3551 and b3781 )
# METSOXR2 ( b1778 and b2582 ) or ( b1778 and b3781 )
# METTRS b2114
# METabcpp b0198 and b0199 and b0197
# METtex b0241 or b0929 or b1377 or b2215
# MG2t3_2pp
# MG2tex b0241 or b0929 or b1377 or b2215
# MG2tpp b3816
# MG2uabcpp b4242
# MGSA b0963
# MI1PP b2533
# MICITDr b0118
# MINCYCtex b1377 or b2215 or b0929 or b0241
# MINCYCtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# MINOHPtexi
# MLDCP1App
# MLDCP1Bpp
# MLDCP2App
# MLDCP2Bpp
# MLDCP3App
# MLDEP1pp
# MLDEP2pp
# MLTG1 b0403
# MLTG2 b0403
# MLTG3 b0403
# MLTG4 b0403
# MLTG5 b0403
# MLTGY1pp b2558 or b2963 or b4392 or b2813 or b2701 or b1193
# MLTGY2pp b1193 or b2558 or b2963 or b4392 or b2813 or b2701
# MLTGY3pp b1193 or b2963 or b2558 or b4392 or b2813 or b2701
# MLTGY4pp b2701 or b1193 or b2963 or b2558 or b4392 or b2813
# MLTP1 b3417
# MLTP2 b3417
# MLTP3 b3417
# MMCD b2919
# MMETt2pp b0260
# MMETtex b0241 or b0929 or b1377 or b2215
# MMM b2917
# MN2t3pp b3915 or b0752
# MN2tpp b3040
# MN6PP b0822
# MNLptspp b3599 and b2415 and b2416
# MNLtex b0241 or b0929 or b1377 or b2215
# MNNH b4322
# MNt2pp b2392
# MNtex b0241 or b0929 or b1377 or b2215
# MOADSUx b2530 and b0784
# MOAT b3633
# MOAT2 b3633
# MOAT3C b3624
# MOBDabcpp ( b0763 and b0764 and b0765 ) or ( b2422 and b2424 and b2423 and b3917 ) or ( b2422 and b2425 and b2424 and b2423 )
# MOBDtex b0241 or b0929 or b1377 or b2215
# MOCDS b2877
# MOCOS b0827
# MOGDS b3857 or ( b3857 and b3856 )
# MOHMT b0134
# MOX
# MPTAT b0009
# MPTG ( b3396 and b1069 ) or ( b0149 and b1069 ) or ( b1069 and b2519 )
# MPTG2 ( b3396 and b1069 ) or ( b0149 and b1069 ) or ( b1069 and b2519 )
# MPTS b0784 and b0785
# MPTSS b0826
# MSAR b1008 or b1539
# MSO3abcpp b0936 and b0933 and b0934
# MSO3tex b0241 or b0929 or b1377 or b2215
# MTAN b0159
# MTHFC b0529
# MTHFD b0529
# MTHFR2 b3941
# MTHTHFSs s0001
# MTRPOX b1059
# N2Otex b0241 or b0929 or b1377 or b2215
# N2Otpp s0001
# NACODA b3957
# NACtex b0241 or b0929 or b1377 or b2215
# NACtpp
# NADDP b3996 or b2411
# NADH10 b1109
# NADH16pp b2276 and b2277 and b2278 and b2279 and b2280 and b2281 and b2282 and b2283 and b2284 and b2285 and b2286 and b2287 and b2288
# NADH17pp b2276 and b2277 and b2278 and b2279 and b2280 and b2281 and b2282 and b2283 and b2284 and b2285 and b2286 and b2287 and b2288
# NADH18pp b2276 and b2277 and b2278 and b2279 and b2280 and b2281 and b2282 and b2283 and b2284 and b2285 and b2286 and b2287 and b2288
# NADH5 b1109
# NADH9 b1109
# NADK b2615
# NADN
# NADPHQR2 b3028
# NADPHQR3 b3028
# NADPHQR4 b3028
# NADPPPS
# NADS1 b1740
# NADTRHD b3962 or ( b1602 and b1603 )
# NAMNPP b0931
# NAt3_1p5pp b1186
# NAt3_2pp b0019
# NAt3pp b0842 or b1216
# NAtex b0241 or b0929 or b1377 or b2215
# NDPK1 b0474 or b2518
# NDPK2 b0474 or b2518
# NDPK3 b2518 or b0474
# NDPK4 b0474 or b2518
# NDPK5 b0474 or b2518
# NDPK6 b2518 or b0474
# NDPK7 b0474 or b2518
# NDPK8 b0474 or b2518
# NH4tex b0241 or b0929 or b1377 or b2215
# NH4tpp b0451 or s0001
# NHFRBO b2710 and b2711
# NI2abcpp b3469
# NI2t3pp b3915 or b0752
# NI2tex b0241 or b0929 or b1377 or b2215
# NI2tpp b3816
# NI2uabcpp ( b3476 and b3477 and b3478 and b3479 and b3480 ) or b4242
# NMNAT b4390 or b0639
# NMNDA
# NMNN
# NMNPtpp b0751
# NMNt7pp
# NMNtex b0241 or b0929 or b1377 or b2215
# NNAM b1768
# NNATr b0639
# NNDMBRT b1991
# NNDPR b0109
# NO2t2rpp b3367 or b1223
# NO2tex b0241 or b0929 or b1377 or b2215
# NO3R1bpp ( b2203 and b2206 ) and b2202 and b2205 and b2204
# NO3R1pp ( b1465 and b1466 and b1467 and b1468 ) or ( b1224 and b1225 and b1226 and b1227 )
# NO3R2bpp ( b2203 and b2206 ) and b2202
# NO3R2pp ( b1465 and b1466 and b1467 and b1468 ) or ( b1224 and b1225 and b1226 and b1227 )
# NO3t7pp b1223 or b1469
# NO3tex b1377 or b0241 or b0929 or b2215
# NODOx b2552
# NODOy b2552
# NOVBCNtex s0001
# NOVBCNtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# NOtex b0241 or b0929 or b1377 or b2215
# NOtpp s0001
# NTD1 b2291 or b2744 or b4374
# NTD10 b2744
# NTD10pp b0480 or b4055
# NTD11 b2744
# NTD11pp b0480 or b4055
# NTD12 b2291 or b2744
# NTD12pp b0480 or b4055
# NTD1pp b0480 or b4055
# NTD2 b2744 or b4374
# NTD2pp b0480 or b4055
# NTD3 b2744 or b2291
# NTD3pp b0480 or b4055
# NTD4 b2744
# NTD4pp b0480 or b4055
# NTD5 b2291 or b2744 or b4374
# NTD5pp b0480 or b4055
# NTD6 b2291 or b2744
# NTD6pp b0480 or b4055
# NTD7 b2744
# NTD7pp b0480 or b4055
# NTD8 b2291 or b2744
# NTD8pp b0480 or b4055
# NTD9 b2744
# NTD9pp b0480 or b4055
# NTP1 b0650 or b4161
# NTP10 b4161 or b4394
# NTP11 b4394
# NTP12 b4394
# NTP3 b4161
# NTP3pp b0980
# NTP5 b4161
# NTPP1 b0099 or b2781
# NTPP10 b2954
# NTPP11 b2954
# NTPP2 b0099 or b2781
# NTPP3 b2781 or b2251 or b1759
# NTPP4 b1759 or b2781
# NTPP5 b2781 or b1865
# NTPP6 b2781
# NTPP7 b2781 or b2251
# NTPP8 b2781
# NTPP9 b2954
# NTPTP1 b0160
# NTPTP2 b0160
# NTRIR2x b3365 and b3366
# NTRIR3pp b4070 and b4071 and b4072 and b4073
# NTRIR4pp b4070 and b4071 and b4072 and b4073
# O16A4COLIPAabctex b3200 and b3201 and b3199 and b4261 and b4262
# O16A4Lpp b3622
# O16AP1pp b2035 and b2027
# O16AP2pp b2035 and b2027
# O16AP3pp b2035 and b2027
# O16AT b2033
# O16AUNDtpp b2037
# O16GALFT b2034
# O16GLCT1 b2032
# O16GLCT2
# O2Stex b1377 or b2215 or b0241 or b0929
# O2tex b0241 or b0929 or b1377 or b2215
# O2tpp s0001
# OAADC b1850
# OBTFL ( ( b0902 and b0903 ) and b2579 ) or ( b0902 and b0903 ) or ( b0902 and b3114 )
# OCBT b4254 or b0273
# OCDCAtexi b2344
# OCDCEAtexi b2344
# OCTAtex b0241 or b0929 or b1377 or b2215
# OCTDPS b3187
# OCTNLL b4386
# OGMEACPD b0180
# OGMEACPR b1093
# OGMEACPS b1091
# OHPBAT b0907
# OHPHM b2232
# OMBZLM b3833
# OMCDC s0001
# OMMBLHX b0662
# OMMBLHX3
# OMPDC b1281
# OMPHHX b2907
# OMPHHX3
# OP4ENH b0350
# OPHBDC b3843 and b2311
# OPHHX b3835
# OPHHX3
# OPMEACPD b0180
# OPMEACPR b1093
# OPMEACPS b2323
# ORNDC b2965 or b0693
# ORNabcpp b2310 and b2307 and b2306 and b2308
# ORNtex b0241 or b0929 or b1377 or b2215
# OROTt2_2pp b3528
# OROTtex b2215 or b1377 or b0929 or b0241
# ORPT b3642
# OXAMTC
# OXCDC b2373
# OXCOAHDH b1387
# OXDHCOAT b1394 and b1397
# P5CD b1014
# P5CR b0386
# PA120abcpp b0914
# PA140abcpp b0914
# PA141abcpp b0914
# PA160abcpp b0914
# PA161abcpp b0914
# PA180abcpp b0914
# PA181abcpp b0914
# PACALDt2rpp
# PACALDtex b0241 or b0929 or b1377 or b2215
# PACCOAE b1388 and b1389 and b1390 and b1391 and b1392
# PACCOAL b1398
# PANTS b0133
# PAPA120 b1278
# PAPA120pp b1278
# PAPA140 b1278
# PAPA140pp b1278
# PAPA141 b1278
# PAPA141pp b1278
# PAPA160 b1278
# PAPA160pp b1278
# PAPA161 b1278
# PAPA161pp b1278
# PAPA180 b1278
# PAPA180pp b1278
# PAPA181 b1278
# PAPA181pp b1278
# PAPPT3 b0087
# PAPSR ( b2762 and b2582 ) or ( b2762 and b3781 )
# PAPSR2 ( b2762 and b0849 ) or ( b2762 and b1064 ) or ( b2762 and b1654 ) or ( b2762 and b3610 )
# PDE1 b1489
# PDE4 b1489
# PDH b0114 and b0115 and b0116
# PDX5PO2
# PDX5POi b1638
# PDX5PS b0052 and b2564
# PDXPP b0766
# PE120abcpp b0914
# PE140abcpp b0914
# PE141abcpp b0914
# PE160abcpp b0914
# PE161abcpp b0914
# PE180abcpp b0914
# PE181abcpp b0914
# PEAMNOpp b1386
# PEAMNtex b0241 or b0929 or b1377 or b2215
# PERD b2320
# PETNT161pp b3546
# PETNT181pp b3546
# PFK b3916 or b1723
# PFK_2 b3916
# PFK_3 b3916
# PFL ( b0902 and b0903 ) or ( b0902 and b3114 ) or ( b3951 and b3952 ) or ( ( b0902 and b0903 ) and b2579 )
# PG120abcpp b0914
# PG140abcpp b0914
# PG141abcpp b0914
# PG160abcpp b0914
# PG161abcpp b0914
# PG180abcpp b0914
# PG181abcpp b0914
# PGAMT b3176
# PGCD b2913
# PGI b4025
# PGK b2926
# PGL b0767
# PGLYCP b3385
# PGM b3612 or b4395 or b0755
# PGMT b2690 or b0688
# PGP120abcpp b0914
# PGP140abcpp b0914
# PGP141abcpp b0914
# PGP160abcpp b0914
# PGP161abcpp b0914
# PGP180abcpp b0914
# PGP181abcpp b0914
# PGPP120 b1278 or b0418
# PGPP120pp b0418 or b1278
# PGPP140 b1278 or b0418
# PGPP140pp b0418 or b1278
# PGPP141 b1278 or b0418
# PGPP141pp b0418 or b1278
# PGPP160 b0418 or b1278
# PGPP160pp b0418 or b1278
# PGPP161 b1278 or b0418
# PGPP161pp b0418 or b1278
# PGPP180 b0418 or b1278
# PGPP180pp b0418 or b1278
# PGPP181 b1278 or b0418
# PGPP181pp b0418 or b1278
# PGSA120 b1912
# PGSA140 b1912
# PGSA141 b1912
# PGSA160 b1912
# PGSA161 b1912
# PGSA180 b1912
# PGSA181 b1912
# PHEMEabcpp b2201 and b2200 and b2199 and b2198 and b2197
# PHEMEtiex
# PHETA1 b4054 or b0928 or b3770
# PHETRS b1713 and b1714
# PHEt2rpp b1473 or b0112 or b0576
# PHEtex b0241 or b0929 or b1377 or b2215
# PHYTSpp b0980
# PIt2rpp b2987 or b3493
# PItex b0241 or b0929 or b1377 or b2215
# PIuabcpp b3726 and b3725 and b3727 and b3728
# PLIPA1A120pp b3821
# PLIPA1A140pp b3821
# PLIPA1A141pp b3821
# PLIPA1A160pp b3821
# PLIPA1A161pp b3821
# PLIPA1A180pp b3821
# PLIPA1A181pp b3821
# PLIPA1E120pp b3821
# PLIPA1E140pp b3821
# PLIPA1E141pp b3821
# PLIPA1E160pp b3821
# PLIPA1E161pp b3821
# PLIPA1E180pp b3821
# PLIPA1E181pp b3821
# PLIPA1G120pp b3821
# PLIPA1G140pp b3821
# PLIPA1G141pp b3821
# PLIPA1G160pp b3821
# PLIPA1G161pp b3821
# PLIPA1G180pp b3821
# PLIPA1G181pp b3821
# PLIPA2A120pp b3821
# PLIPA2A140pp b3821
# PLIPA2A141pp b3821
# PLIPA2A160pp b3821
# PLIPA2A161pp b3821
# PLIPA2A180pp b3821
# PLIPA2A181pp b3821
# PLIPA2E120pp b3821
# PLIPA2E140pp b3821
# PLIPA2E141pp b3821
# PLIPA2E160pp b3821
# PLIPA2E161pp b3821
# PLIPA2E180pp b3821
# PLIPA2E181pp b3821
# PLIPA2G120pp b3821
# PLIPA2G140pp b3821
# PLIPA2G141pp b3821
# PLIPA2G160pp b3821
# PLIPA2G161pp b3821
# PLIPA2G180pp b3821
# PLIPA2G181pp b3821
# PMANM b2048
# PMDPHT
# PMEACPE b3412
# PMPK b2103
# PNTK b3974
# PNTOt4pp b3258
# PNTOtex b0241 or b0929 or b1377 or b2215
# POAACR b1010
# POR5 ( b0684 and b1378 ) or ( b2895 and b1378 )
# POX b0871
# PPA b2744 or b4226 or b2502
# PPA2 b2502 or b2744
# PPAKr b3115
# PPALtex b0241 or b0929 or b1377 or b2215
# PPALtpp
# PPAt4pp b1015
# PPAtex b1377 or b0929 or b2215 or b0241
# PPBNGS b0369
# PPC b3956
# PPCDC b3639
# PPCK b3403
# PPCSCT b2920
# PPGPPDP b3650
# PPK2r b2501
# PPKr b2501
# PPM b3380 or b4383
# PPM2 b4383
# PPNCL2 b3639
# PPND b2600
# PPNDH b2599
# PPPGO b3850
# PPPGO3 b3850
# PPPNDO b2538 and b2539 and b2540 and b2542
# PPPNt2rpp b2536
# PPPNtex b0241 or b0929 or b1377 or b2215
# PPS b1702
# PPTHpp b0383
# PPTtex b0241 or b0929 or b1377 or b2215
# PRAGSr b4005
# PRAIS b2499
# PRAIi b1262
# PRAMPC b2026
# PRASCSi b2476
# PRATPP b2026
# PRFGS b2557
# PRMICI b2024
# PROD2 b1014
# PROGLYabcpp b3544 and b3543 and b3542 and b3541 and b3540
# PROGLYtex b0241 or b0929 or b1377 or b2215
# PROTRS b0194
# PROabcpp b2677 and b2678 and b2679
# PROt2rpp b4111
# PROt4pp b1015
# PROtex b1377 or b2215 or b0241 or b0929
# PRPPS b1207
# PSCLYSt2pp b3370
# PSCLYStex b2215 or b1377 or b0241 or b0929
# PSCVT b0908
# PSD120 b4160
# PSD140 b4160
# PSD141 b4160
# PSD160 b4160
# PSD161 b4160
# PSD180 b4160
# PSD181 b4160
# PSERT b0907
# PSERtex b0241 or b0929 or b1377 or b2215
# PSP_L b4388
# PSP_Lpp b4055
# PSSA120 b2585
# PSSA140 b2585
# PSSA141 b2585
# PSSA160 b2585
# PSSA161 b2585
# PSSA180 b2585
# PSSA181 b2585
# PTA2 b2297
# PTAr b2297 or b2458
# PTHRpp b4055
# PTPATi b3634
# PTRCORNt7pp b0692
# PTRCTA b3073
# PTRCabcpp ( b0854 and b0855 and b0856 and b0857 ) or ( b1126 and b1125 and b1124 and b1123 ) or ( b1440 and b1441 and b1442 and b1443 )
# PTRCt2pp b1296 or b0692
# PTRCtex b0241 or b0929 or b1377 or b2215
# PUNP1 b4384
# PUNP2 b4384
# PUNP3 b2407 or b4384
# PUNP4 b2407 or b4384
# PUNP5 b2407 or b4384
# PUNP6 b2407 or b4384
# PUNP7 b2407
# PYAM5PO b1638
# PYDAMK b2418
# PYDAMtex b2215 or b0929 or b1377 or b0241
# PYDAMtpp
# PYDXK b1636 or b2418
# PYDXNK b2418
# PYDXNtex b2215 or b0929 or b1377 or b0241
# PYDXNtpp
# PYDXPP b0446 or b3826 or b0766
# PYDXtex b2215 or b0929 or b1377 or b0241
# PYDXtpp
# PYK b1854 or b1676
# PYNP2r b3831
# PYROX b1012 and b1007
# PYRt2rpp
# PYRtex b0241 or b0929 or b1377 or b2215
# QMO2 b3029
# QMO3 b3029
# QUIN2tex b2215 or b1377 or b0241 or b0929
# QUIN2tpp
# QUINDH b1692
# QULNS b0750
# R15BPK b4094
# R1PK
# R5PP b0822
# R5PPpp b4055
# R5Ptex b0241 or b0929 or b1377 or b2215
# RBFK b0025
# RBFSa b1662
# RBFSb b0415
# RBK b3752
# RBK_L1 b0063
# RBP4E b4198 or b3583 or b0061
# REPHACCOAI b1394
# RFAMPtex s0001
# RFAMPtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# RHAT1 b3629
# RHCCE b2687
# RIBabcpp ( b4231 and b4227 and b4485 and b4230 ) or ( b3749 and b3751 and b3750 and b3748 ) or ( b4087 and b4088 and b4086 )
# RIBtex b0241 or b0929 or b1377 or b2215
# RMI b3903
# RMK b3904
# RMNtex b2215 or b0241 or b0929 or b1377
# RMNtpp b3907
# RMPA b3902
# RNDR1 ( ( b2234 and b2235 ) and b2582 ) or ( ( b2234 and b2235 ) and b3781 )
# RNDR1b ( b1064 and ( b2675 and b2676 ) ) or ( b3610 and ( b2675 and b2676 ) ) or ( b1654 and ( b2675 and b2676 ) ) or ( b0849 and ( b2675 and b2676 ) )
# RNDR2 ( ( b2234 and b2235 ) and b3781 ) or ( ( b2234 and b2235 ) and b2582 )
# RNDR2b ( b0849 and ( b2675 and b2676 ) ) or ( b3610 and ( b2675 and b2676 ) ) or ( b1064 and ( b2675 and b2676 ) ) or ( b1654 and ( b2675 and b2676 ) )
# RNDR3 ( ( b2234 and b2235 ) and b3781 ) or ( ( b2234 and b2235 ) and b2582 )
# RNDR3b ( b0849 and ( b2675 and b2676 ) ) or ( b3610 and ( b2675 and b2676 ) ) or ( b1654 and ( b2675 and b2676 ) ) or ( b1064 and ( b2675 and b2676 ) )
# RNDR4 ( ( b2234 and b2235 ) and b3781 ) or ( ( b2234 and b2235 ) and b2582 )
# RNDR4b ( b0849 and ( b2675 and b2676 ) ) or ( b1064 and ( b2675 and b2676 ) ) or ( b3610 and ( b2675 and b2676 ) ) or ( b1654 and ( b2675 and b2676 ) )
# RNTR1c2 ( b0684 and b3924 and b4238 and b4237 ) or ( b2895 and b3924 and b4238 and b4237 ) or ( b0684 and b4238 ) or ( b2895 and b4238 )
# RNTR2c2 ( b0684 and b3924 and b4238 and b4237 ) or ( b2895 and b3924 and b4238 and b4237 ) or ( b0684 and b4238 ) or ( b2895 and b4238 )
# RNTR3c2 ( b0684 and b3924 and b4238 and b4237 ) or ( b2895 and b3924 and b4238 and b4237 ) or ( b0684 and b4238 ) or ( b2895 and b4238 )
# RNTR4c2 ( b0684 and b3924 and b4238 and b4237 ) or ( b2895 and b3924 and b4238 and b4237 ) or ( b0684 and b4238 ) or ( b2895 and b4238 )
# RPE b4301 or b3386
# RPI b2914 or b4090
# RZ5PP b0638
# S2FE2SR b1683 and b1682 and b1681 and b1679 and b1680
# S2FE2SS b3807 and b1683 and b1682 and b1681 and b1679 and b1680
# S2FE2SS2 b3807 and b1683 and b1682 and b1681 and b1679 and b1680
# S2FE2ST b1684 and b1683 and b1682 and b1681
# S4FE4SR b1683 and b1682 and b1681
# S4FE4ST b1684 and b1683 and b1682 and b1681
# S7PI b0222
# SADH b1745
# SADT2 b2751 and b2752
# SARCOX b1059
# SBTPD b2705
# SBTptspp b2415 and b2416 and b2702 and b2704 and b2703
# SBTtex b0241 or b0929 or b1377 or b2215
# SCYSDS b1679 and b1680
# SDPDS b2472
# SDPTA b3359
# SELCYSS b3591
# SELGTHR
# SELGTHR2
# SELGTHR3
# SELNPS b1764
# SELR b1587 and b1588 and b1589 and b1590
# SELtex b1377 or b0929 or b2215 or b0241
# SELtpp b2422 and b2425 and b2424 and b2423
# SEPHCHCS b2264
# SERASr b0586
# SERAT b3607
# SERD_D b2366
# SERD_L b4471 or b1814 or b2797 or b3708
# SERTRS b0893
# SERTRS2 b0893
# SERt2rpp b2796 or b3116
# SERt4pp b3089
# SERtex b0241 or b0929 or b1377 or b2215
# SFGTHi b2154 or b0355
# SGDS b1744
# SGSAD b1746
# SHCHCS3 b2263
# SHCHD2 b3368
# SHCHF b3368
# SHK3Dr b1692 or b3281
# SHKK b3390 or b0388
# SHSL1 b3939
# SKMt2pp b1981
# SKMtex b0241 or b0929 or b1377 or b2215
# SLNTtex b1377 or b0929 or b2215 or b0241
# SLNTtpp b2422 and b2425 and b2424 and b2423
# SO2tex b0241 or b0929 or b1377 or b2215
# SO2tpp s0001
# SO3tex b0241 or b0929 or b1377 or b2215
# SO4t2pp b1206
# SO4tex b0241 or b0929 or b1377 or b2215
# SOTA b1748
# SPMDAT1 b1584
# SPMDAT2 b1584
# SPMDabcpp ( b1126 and b1125 and b1124 and b1123 ) or ( b1440 and b1441 and b1442 and b1443 )
# SPMDt3pp b1599 and b1600
# SPMDtex b0241 or b0929 or b1377 or b2215
# SPMS b0121
# SPODM b3908 or b1656
# SPODMpp b1646
# SSALx b1525
# SSALy b2661 or b1525
# SUCASPtpp b4138 or b4123 or b0621
# SUCBZL b2260
# SUCBZS b2261
# SUCCt2_2pp b3528
# SUCCt2_3pp b4123 or b4138
# SUCCt3pp
# SUCCtex b0241 or b0929 or b1377 or b2215
# SUCDi b0721 and b0722 and b0723 and b0724
# SUCFUMtpp b4123 or b0621 or b4138
# SUCMALtpp b4138 or b4123 or b0621
# SUCOAS b0728 and b0729
# SUCRtex b0241 or b0929 or b1377 or b2215
# SUCTARTtpp b4123
# SUCptspp b2417 and b2429 and b2415 and b2416
# SULFACabcpp b0936 and b0933 and b0934
# SULFACtex b1377 or b2215 or b0241 or b0929
# SULRi b2763 and b2764
# SULabcpp ( b2422 and b2425 and b2424 and b2423 ) or ( b0763 and b0764 and b0765 ) or ( b2422 and b2424 and b2423 and b3917 )
# T2DECAI b0954
# TAGURr b1521
# TALA b2464 or b0008
# TARTD b3061 and b3062
# TARTRDtex b1377 or b2215 or b0241 or b0929
# TARTRt7pp b3063
# TARTRtex b0241 or b0929 or b1377 or b2215
# TARTt2_3pp b4123
# TAUDO b0368
# TAURabcpp b0365 and b0366 and b0367
# TAURtex b0241 or b0929 or b1377 or b2215
# TCYNTtex b0241 or b0929 or b1377 or b2215
# TDP b1134
# TDPADGAT b3790
# TDPAGTA b3791
# TDPDRE b2038
# TDPDRR b2040
# TDPGDH b3788 or b2041
# TDSK b0915
# TDSR1 b2893 and b4136
# TDSR2 b4136 and b0604
# TGBPA ( b3132 and b3137 ) or ( b2095 and b2096 )
# THD2pp b1602 and b1603
# THDPS b0166
# THFAT b2551
# THIORDXi ( b2480 and b3781 ) or ( b2480 and b2582 ) or b1710
# THMDt2pp b2393 or b2964
# THMDt2rpp b2406
# THMDtex b0241 or b0929 or b1377 or b2215
# THMabcpp b0068 and b0067 and b0066
# THMtex b0241 or b0929 or b1377 or b2215
# THRA2i b2551 or b0870
# THRAi b2551 or b0870
# THRD b3616
# THRD_L b3117 or b3772
# THRPtex b0241 or b0929 or b1377 or b2215
# THRS b0004
# THRTRS b1719
# THRabcpp b3454 and b3455 and b3457 and b3460 and b3456
# THRt2pp b0813 or b3823
# THRt2rpp b3116
# THRt4pp b3089
# THRtex b0241 or b0929 or b1377 or b2215
# THYMt3pp
# THYMtex b0929 or b1377 or b2215 or b0241
# THZPSN3 b2530 and b3992 and b3990 and b0423 and b4407
# TKT1 b2935 or b2465
# TKT2 b2935 or b2465
# TMAOR1 ( b0894 and b0895 and b0896 ) or ( b1587 and b1588 and b1589 and b1590 )
# TMAOR1pp ( b0996 and b0997 ) or ( b1872 and b1873 )
# TMAOR2 b0894 and b0895 and b0896
# TMAOR2pp ( b0996 and b0997 ) or ( b1872 and b1873 )
# TMAOtex b0241 or b0929 or b1377 or b2215
# TMAtex b0241 or b0929 or b1377 or b2215
# TMDK1 b1238
# TMDPP b4382
# TMDS b2827
# TMK b1106
# TMPK b0417
# TMPPP b3993
# TPI b3919
# TPRDCOAS b0613
# TRDR ( b3781 and b0888 ) or ( b0888 and b2582 )
# TRE6PH b4239
# TRE6PP b1897
# TRE6PS b1896
# TREH b3519
# TREHpp b1197
# TREptspp b2417 and b2415 and b2416 and b4240
# TREtex b0241 or b0929 or b1377 or b2215
# TRPAS2 b3708
# TRPS1 b1260 and b1261
# TRPS2 b1260 and b1261
# TRPS3 b1260 and b1261
# TRPTRS b3384
# TRPt2rpp b3161 or b3709 or b1473 or b0112
# TRPtex b0241 or b0929 or b1377 or b2215
# TRSARr b0509 or b3125
# TSULabcpp ( b2422 and b2425 and b2424 and b2423 ) or ( b2422 and b2424 and b2423 and b3917 )
# TSULtex b0241 or b0929 or b1377 or b2215
# TTDCAtexi b2344
# TTDCEAtexi b2344
# TTRCYCtex b1377 or b2215 or b0929 or b0241
# TTRCYCtpp ( b0463 and b0462 and b3035 ) or ( b0463 and b2470 and b3035 )
# TUNGSabcpp b0763 and b0764 and b0765
# TUNGStex b2215 or b1377 or b0241 or b0929
# TYMtex b0241 or b0929 or b1377 or b2215
# TYRL b3991
# TYROXDApp b1386
# TYRPpp b4055
# TYRPtex b2215 or b0241 or b0929 or b1377
# TYRTA b4054 or b0928
# TYRTRS b1637
# TYRt2rpp b1473 or b1907 or b0112 or b0576
# TYRtex b0241 or b0929 or b1377 or b2215
# ThDPAT
# U23GAAT b0179
# UAAGDS b0085
# UACGALPpp b0480
# UACGAMPpp b0480
# UACGAMtex b0241 or b0929 or b1377 or b2215
# UACMAMO b3787
# UAG2E b3786
# UAGAAT b1094 and b0181
# UAGCVT b3189
# UAGDP b3730
# UAGPT3 b0090
# UAMAGS b0088
# UAMAS b0091
# UAPGR b3972
# UDCPDP b0841 or b1278 or b3057
# UDCPDPS b0174
# UDCPDPpp b1278 or b3057 or b0841
# UDCPPtppi
# UDPACGALtex b0241 or b0929 or b1377 or b2215
# UDPG4E b0759
# UDPGALM b2036
# UDPGALPpp b0480
# UDPGALtex b0241 or b0929 or b1377 or b2215
# UDPGD b2028
# UDPGDC b2255
# UDPGLCURtex b0241 or b0929 or b1377 or b2215
# UDPGPpp b0480
# UDPGtex b0241 or b0929 or b1377 or b2215
# UDPKAAT b2253
# UGLCURPpp b0480
# UGLT b0758
# UGLYCH b0505
# UGMDDS b0086
# UHGADA b0096
# ULA4NFT b2255
# ULA4Ntppi b4544 and b2258
# UM3PL b4233
# UM4PCP b1192
# UM4PL b4233
# UMPK b0910 or b0171
# UMPtex b0929 or b1377 or b2215 or b0241
# UPLA4FNF b2256
# UPLA4FNT b2254
# UPP3MT b3803 or b3368
# UPP3S b3804
# UPPDC1 b3997
# UPPRT b2498
# URACPAH b1011
# URAt2pp b2497
# URAt2rpp b1006
# URAtex b0241 or b0929 or b1377 or b2215
# URDGLYCD b0517
# UREAtex b0241 or b0929 or b1377 or b2215
# UREAtpp b3927
# URIC
# URIH b2162 or b0651 or b0030
# URIK2 b2066
# URIt2pp b2393 or b2964
# URIt2rpp b2406
# URItex b0411
# USHD b0524
# VALTA b3770
# VALTRS b4258
# VALabcpp b3454 and b3455 and b3457 and b3460 and b3456
# VALt2rpp b0401 or ( b2683 and b2682 )
# VALtex b0241 or b0929 or b1377 or b2215
# VPAMTr b3572
# WCOS b0827
# X5PL3E b4197
# XAND b2866 and b2867 and b2868
# XANt2pp b3654 or b2882
# XANtex b0241 or b0929 or b1377 or b2215
# XANtpp
# XMPtex b0241 or b0929 or b1377 or b2215
# XPPT b0238
# XTSNH b0030
# XTSNt2rpp b2406
# XTSNtex b0241 or b0929 or b1377 or b2215
# XYLI1 b3565
# XYLI2 b3565
# XYLK b0063 or b3564
# XYLK2 b0063 or b3580
# XYLUt2pp b3577 and b3578 and b3579
# XYLUtex b0241 or b0929 or b1377 or b2215
# XYLabcpp b3566 and b3567 and b3568
# XYLt2pp b4031
# XYLtex b0241 or b0929 or b1377 or b2215
# ZN2abcpp b3469
# ZN2t3pp b3915 or b0752
# ZN2tpp b3040
# ZNabcpp b1857 and b1859 and b1858
# Zn2tex b0241 or b0929 or b1377 or b2215

# %%
# First we compute the reference FBA

fba_ref = model.optimize()

# Then we perfom a single gene deletion
sgd = cobra.flux_analysis.single_gene_deletion(model)


# Finally, we extract the potential gene targets
growth=sgd.get("growth").to_dict()    # gets the column growth and convert it to a dictionary (easier to handle)

for r in growth:
    if growth.get(r) < 0.9*fba_ref.objective_value:
        print(list(r)[0], growth.get(r))

# notice that "list(r)[0]" is just a trick to obtain a prettier printing. 
# Indeed, r is a frozenset that contains a single element. We get this element by converting r to a list and 
# then getting its first element.
# Out:
# b3639 1.1865636295458597e-13
# b3648 1.8221586184331884e-15
# b3255 -3.796390251101561e-13
# b3770 -3.747576475941743e-29
# b3733 0.40247730149072236
# b0174 -1.4035757032027264e-16
# b2285 0.8735946118745951
# b2022 -3.4508412209925173e-16
# b2020 -3.4508412209925173e-16
# b0025 9.477433930420358e-18
# b3200 5.1658110132852925e-15
# b0423 4.6854167275055913e-17
# b0087 0.0
# b1208 -2.3238946096362293e-17
# b1693 -6.003207674580763e-17
# b3737 0.40247730149071637
# b1262 0.0
# b2780 -4.616548491428268e-16
# b3990 2.6538449627670946e-16
# b2687 0.0
# b0072 4.839364343869408e-16
# b0783 5.776015507198971e-16
# b0415 9.366511633295629e-17
# b1740 3.501559772967099e-13
# b3433 3.1189600141526575e-16
# b0475 6.698427492931647e-16
# b2926 0.8560604810974046
# b4006 3.6723768030887366e-14
# b2323 0.0
# b3172 2.6497213855017947e-16
# b2021 -2.497951403117288e-16
# b3058 -1.7505854023793835e-13
# b3633 0.0
# b3738 0.40247730149071204
# b1136 1.4480742002348528e-16
# b2287 0.873594611874603
# b3359 -1.5211668738862584e-17
# b3256 0.0
# b2827 0.0
# b0928 -1.581837292425298e-14
# b4039 0.0
# b1096 -2.7331222326973196e-16
# b3734 0.40247730149072164
# b2311 -2.7728542353380627e-17
# b3972 0.0
# b0639 -4.551419396745778e-13
# b2472 1.1364219957759682e-15
# b0031 -6.056589427933038e-16
# b3731 0.4024773014907234
# b3189 0.0
# b4407 7.990665212502926e-15
# b2282 0.8735946118739785
# b2752 4.552792597390629e-13
# b3857 -4.250237467658733e-16
# b2600 -4.590969740571603e-16
# b1091 -2.755415122057195e-16
# b4040 1.0999644152927903e-15
# b0774 6.326844548030928e-19
# b2277 0.8735946118745954
# b3730 -7.622652468864759e-31
# b2762 3.019618919353156e-16
# b2279 0.8735946118746081
# b0052 0.0
# b0750 -2.613031943540902e-12
# b0907 2.9150039772619166e-17
# b1812 0.0
# b0185 -2.7279469830020446e-31
# b3804 -2.042609771006427e-15
# b2515 -1.639146040210684e-15
# b4005 2.03387916826142e-14
# b3993 5.58546840930431e-16
# b2019 1.1038532300385751e-16
# b3196 -5.61849870474453e-17
# b0181 0.0
# b2747 0.0
# b0071 5.270437168226095e-16
# b0085 2.9199456828281705e-16
# b0417 2.892627336343805e-16
# b3997 2.892627336343805e-16
# b3368 2.892627336343805e-16
# b1277 -5.4080045767593e-16
# b3041 4.618328481755358e-16
# b0420 1.907837002954631e-14
# b3805 7.881193145009704e-14
# b1092 0.0
# b2818 -2.645582466542493e-15
# b0159 2.8993750845940185e-15
# b0103 2.061205424488918e-12
# b3642 3.0396448881067553e-16
# b3199 6.557880724285228e-17
# b2283 0.873594611874477
# b2280 0.873594611874477
# b4261 2.61460492452289e-16
# b2574 1.844749030080039e-15
# b3774 0.0
# b3809 0.0
# b2400 -4.699194395460787e-13
# b0776 0.0
# b0182 1.3664629129072576e-13
# b0133 1.1948454631066016e-14
# b0522 9.580889737002519e-15
# b3389 1.5431460900730214e-16
# b0781 0.0
# b0003 0.0
# b2764 -2.040041131876234e-16
# b0421 0.0
# b0086 0.0
# b3957 0.0
# b2530 0.0
# b0091 0.0
# b0073 0.0
# b0175 3.7415213375922803e-16
# b3843 8.314491861316179e-17
# b0523 -1.1407186191522465e-15
# b3729 0.0
# b1415 -1.7529295952409288e-16
# b0775 -5.415775046855346e-16
# b3736 0.4024773014907221
# b0778 -4.309239318256439e-17
# b2476 -2.2744390558035453e-14
# b1288 0.0
# b3360 -9.946623069699865e-14
# b4262 3.558652549795353e-16
# b2103 0.0
# b2507 2.0848627629661876e-16
# b2763 2.0848627629661876e-16
# b0908 -1.4196393862802103e-16
# b1215 -1.9421012015729503e-31
# b4013 2.39209935116413e-16
# b0826 -1.5928413864225545e-16
# b2312 -6.145709836992413e-15
# b4160 0.0
# b0369 0.0
# b1094 0.0
# b3608 0.0
# b3958 -7.523685107512839e-16
# b0179 0.0
# b2276 0.873594611874598
# s0001 -4.390751042305526e-17
# b1210 -3.224542011870044e-16
# b3994 -1.0468448766737683e-16
# b1263 -6.542780479211052e-16
# b2585 0.0
# b2320 0.0
# b0524 0.0
# b3735 0.4024773014907216
# b1261 0.0
# b3607 -2.920315958113902e-17
# b3177 2.920315958113902e-17
# b0134 1.0212940441594644e-12
# b2025 6.538039307586451e-16
# b0777 0.0
# b0029 -6.28391834059767e-16
# b2746 -1.1527306480172374e-14
# b0915 -6.941165505421325e-15
# b0074 0.0
# b0918 0.0
# b2557 -8.301104888795801e-14
# b1662 6.248751609329589e-16
# b3771 1.1762911273858988e-16
# b3967 -2.2051951813336298e-16
# b0785 -4.363640078198723e-14
# b3974 -3.5055729834369794e-12
# b0180 3.8942328557721985e-16
# b4177 -2.10806519442304e-13
# b2564 -1.3688553395765753e-16
# b3176 -3.174580527909157e-18
# b0090 0.0
# b3941 -3.19626608500117e-14
# b2315 1.3469998953708489e-17
# b1098 7.135745355680957e-16
# b2024 2.6759045083803587e-16
# b1260 -4.437873478813504e-16
# b0720 -4.2410355943537525e-15
# b1093 1.501711736716564e-14
# b0009 -6.58005271572485e-14
# b2316 7.86758151923503e-15
# b0109 -2.046587547782376e-12
# b2284 0.873594611874601
# b2023 6.971671243491595e-16
# b0414 -5.577336994793276e-16
# b2026 -3.049471490534913e-16
# b3960 4.971964386741706e-17
# b3991 -4.4747679480675356e-17
# b1264 4.3602925314269646e-16
# b3850 -6.941585710031728e-13
# b2288 0.8735946118745949
# b0173 0.0
# b1069 2.9113578484015834e-16
# b0096 1.4414944206358088e-14
# b1779 0.8560604810974043
# b3412 -1.8131102142836553e-12
# b3198 -4.081341189323788e-17
# b0131 3.718792583452051e-12
# b2278 0.8735946118746021
# b0386 9.184970605666026e-17
# b4214 -5.149189310462488e-16
# b0088 -1.2088013834586353e-16
# b0004 0.0
# b3187 0.0
# b3959 -4.7635608552638087e-17
# b0914 0.0
# b3201 1.3119022946544096e-15
# b3992 0.0
# b2499 4.591153173517505e-16
# b3634 0.0
# b2599 0.0
# b2478 0.0
# b2751 -3.4064040203829507e-16
# b0166 0.0
# b3040 0.0
# b4245 0.0
# b2750 5.484868072387384e-17
# b3018 0.0
# b2153 0.0
# b3939 7.180815476262415e-16
# b2281 0.8735946118745777
# b3807 -1.289116206166167e-15
# b1281 -5.2034922565944126e-15
# b0154 0.0
# b2942 2.5466319793127875e-17
# b3732 0.40247730149072003
# b2329 9.662517250024987e-16
# b2615 4.732712268477933e-12
# b2838 0.0
# b0784 0.0
# b1062 0.0
# b2286 0.8735946118746014
# b0142 0.0
# b0827 0.0
# b1131 3.2500420066584052e-15

# %% [markdown]
# # ⚠️ Important sample code
#
# Imagine that you can (in silico) knocked-out a gene encoding for an enzyme which catabolize one or several reactions (following some logical rules) and computes the resulting effect on the objective function.
# This is what is computed by the following code
#
#     sgd = cobra.flux_analysis.single_gene_deletion(model)
#
# Notice that by default, it computes the new objective value by using a FBA computation. A MOMA method can be used instead with
#
#     sgd = cobra.flux_analysis.single_gene_deletion(model, method = "MOMA")

# %% [markdown]
# *Exercise 4*
#
# This question can be tested by using any available e. coli model…
# What is the optimal O2 condition if we want to produce alcohol with e. coli ? More precisely, we want to keep e. coli alive (so biomass>90% from its optimal), optimize the ethanol production and change the O2 rate exchange to see when the ethanol production is maximal…

# %%
# we will take here the Escherichia coli str. K-12 substr. MG1655 (model iAF1260.json in the BIGG repository)

model = cobra.io.load_json_model("iAF1260.json")

fba = model.optimize()

print("Optimal growth rate = ",fba.objective_value)
print("Ethanol output rate = ",fba.fluxes.get("EX_etoh_e"))

# conclusion, there is no ethanol production when the biomass is at its maximum
# Out:
# Optimal growth rate =  0.7367009388648819
# Ethanol output rate =  0.0

# %%
# Our goal is to compute the line of best compromise between biomass growth and ethanol production.

fba_ref = model.optimize()

nb_points = 20

optimal_growth=list()
optimal_ethanol=list()

# we now change the objective to ethanol production

model.objective = model.reactions.EX_etoh_e.flux_expression

for i in range(nb_points+1):
    current_growth_value = i*fba_ref.objective_value/nb_points
    optimal_growth.append(current_growth_value)
    model.reactions.BIOMASS_Ec_iAF1260_core_59p81M.lower_bound = current_growth_value
    model.reactions.BIOMASS_Ec_iAF1260_core_59p81M.upper_bound = current_growth_value
    fba = model.optimize() # now it computes the best ethanol production
    optimal_ethanol.append(fba.objective_value)

# plot the results
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(optimal_growth,optimal_ethanol)
plt.show()

# %%
import cobra
import matplotlib.pyplot as plt
# %matplotlib inline

model_ref = cobra.io.load_json_model("iAF1260.json")

nb_points = 20

# question : does it changes something if one puts the system in some anaerobic conditions ?

allresults=list()

for o2 in range(2,17):
    model = model_ref.copy()
    model.reactions.EX_o2_e.lower_bound=-o2 # we set the o2 condition
    fba_ref = model.optimize()
    # same as previously ?
    model.objective = model.reactions.EX_etoh_e.flux_expression
    optimal_growth=list()
    optimal_ethanol=list()

    for i in range(nb_points+1):
        current_growth_value = i*fba_ref.objective_value/nb_points
        optimal_growth.append(current_growth_value)
        model.reactions.BIOMASS_Ec_iAF1260_core_59p81M.lower_bound = current_growth_value
        model.reactions.BIOMASS_Ec_iAF1260_core_59p81M.upper_bound = current_growth_value
        fba = model.optimize() # now it computes the best ethanol production
        optimal_ethanol.append(fba.objective_value)
        
    plt.plot(optimal_growth,optimal_ethanol)
# show all

plt.show()

# Has it can be noted in the following plot, changing the o2 availibility has an effect on the biolmass growth 
# but not ethanol. A goog choice of o2 condition (close to anaerobic condition) will allow to have a good putative
# production of ethanol while an acceptable growth rate.

# %% [markdown]
# # Metabolism and cancer…
#
# There exists two main models repositories containing metabolic networks relative to human health : Virtual Metabolic Human, VMH ([https://vmh.uni.lu/](https://vmh.uni.lu/)) and Human Metabolic Atlas, HMA ([http://www.metabolicatlas.org/](http://www.metabolicatlas.org/)). Take a short tour on these repositories.

# %% [markdown]
# *Exercise 5*
#
# Consider first the HMA. Take 3 models of distinct cancer and compare the models by constructing Venn diagrams comparing the common reactions, the common genes,…
#
# Notice that you will find three models from HMA in the moodle web site formatted in JSON exchange format.
# The models can be loaded in python by using the cobra.io.load_json_model function.
#
# Venn diagrams can be displayed by using the matplotlib-venn library (see [https://pypi.org/project/matplotlib-venn/](https://pypi.org/project/matplotlib-venn/) for details).

# %%
# An example showing how to use the matplotlib-venn library
from matplotlib_venn import venn3

only_in_1 = 2
only_in_2 = 5
only_in_3 = 9

in_1_and_2 = 7
in_1_and_3 = 17
in_2_and_3 = 8

in_1_and_2_and_3 = 3

# take care of the order
data = (only_in_1, only_in_2, in_1_and_2, only_in_3, in_1_and_3, in_2_and_3, in_1_and_2_and_3)

venn3(subsets = data, set_labels = ('Set1', 'Set2', 'Set3'))

# %% [markdown]
# # ✋
#
# *Antimetabolites* are small molecules that mimics the chemical affinities of a given metabolite except, such taking its place in the chemical reactions, excepts that it blocks the functionality of the metabolite (i.e., the chemical reaction has no effects). They are commonly used as efficient cancer treatment strategies. It is thus possible, in a in silico study to block all reactions having a given metabolite as substrate and to report the metabolite having an effect on the cell growth.

# %% [markdown]
# *Exercise 6*
#
# Consider the e coli model of BiGG and find antimetabolites having a putative effect.

# %%
import cobra
model = cobra.io.read_sbml_model('e_coli_core.xml')

fbaref = model.optimize()

for m2 in model.metabolites:
    copiemodele = model.copy()
    m = copiemodele.metabolites.get_by_id(m2.id)
    for r in m.reactions:
        if m in r.reactants:
            r.lower_bound = 0
            r.upper_bound = 0
    fba = copiemodele.optimize()
    if (fba.objective_value < 0.9*fbaref.objective_value):
        print(m.id,'is a putative antimetabolite, effect = ',fba.objective_value/fbaref.objective_value)
# Out:
# 2pg_c is a putative antimetabolite, effect =  1.7841401720380862e-15
# 3pg_c is a putative antimetabolite, effect =  0.0
# accoa_c is a putative antimetabolite, effect =  0.0
# acon_C_c is a putative antimetabolite, effect =  5.642462399892346e-18
# adp_c is a putative antimetabolite, effect =  0.32143933947969283
# atp_c is a putative antimetabolite, effect =  -9.355066317488418e-16
# cit_c is a putative antimetabolite, effect =  5.642462399892346e-18
# co2_e is a putative antimetabolite, effect =  0.5282735468561991
# coa_c is a putative antimetabolite, effect =  2.4657786782949867e-15
# dhap_c is a putative antimetabolite, effect =  0.8056066159777673
# e4p_c is a putative antimetabolite, effect =  0.0
# f6p_c is a putative antimetabolite, effect =  0.0
# fdp_c is a putative antimetabolite, effect =  0.8056066159777682
# g3p_c is a putative antimetabolite, effect =  0.0
# g6p_c is a putative antimetabolite, effect =  0.0
# glc__D_e is a putative antimetabolite, effect =  -0.05184915198586839
# gln__L_c is a putative antimetabolite, effect =  0.0
# glu__L_c is a putative antimetabolite, effect =  -3.2352999717326008e-15
# h2o_c is a putative antimetabolite, effect =  0.0
# h2o_e is a putative antimetabolite, effect =  0.43884427404375503
# h_c is a putative antimetabolite, effect =  0.14054005034978587
# h_e is a putative antimetabolite, effect =  0.0
# icit_c is a putative antimetabolite, effect =  -9.394445955688737e-18
# nad_c is a putative antimetabolite, effect =  -2.707718072929896e-16
# nadh_c is a putative antimetabolite, effect =  0.23750071316435648
# nadp_c is a putative antimetabolite, effect =  1.5018029543045295e-16
# nadph_c is a putative antimetabolite, effect =  0.0
# nh4_c is a putative antimetabolite, effect =  -7.626197592651902e-16
# nh4_e is a putative antimetabolite, effect =  -1.5205093353167173e-15
# o2_c is a putative antimetabolite, effect =  0.2421990396706857
# o2_e is a putative antimetabolite, effect =  0.2421990396706857
# oaa_c is a putative antimetabolite, effect =  0.0
# pep_c is a putative antimetabolite, effect =  0.0
# pi_c is a putative antimetabolite, effect =  0.0
# pi_e is a putative antimetabolite, effect =  -5.332479173799869e-15
# pyr_c is a putative antimetabolite, effect =  1.9618168238420088e-15
# q8_c is a putative antimetabolite, effect =  0.24219903967068576
# q8h2_c is a putative antimetabolite, effect =  0.24219903967068754
# r5p_c is a putative antimetabolite, effect =  0.0
# xu5p__D_c is a putative antimetabolite, effect =  -1.6695606729043704e-15

# %% [markdown]
# *Exercise 7*
#
# The repository VMH contains the description of different diet conditions. Take some microbiote models from the download section and test the effect of different diet conditions on the biomass production and on the cholesterol export.
